# %%
import numpy as np
import modin.pandas as mipd
import os
import time
import pandas as pd
from tqdm import tqdm
import networkx as nx
from networkx.algorithms import bipartite
import matplotlib.pyplot as plt
import numpy as np
import gc

from matplotlib import pyplot as plt

# %%
time_resolution = 1
c_path = './network_data'+str(time_resolution)+'/commits/'
e_path = './network_data'+str(time_resolution)+'/emails/'

all_graduated_name = np.load('./all_graduated.npy').tolist()
all_graduated = [x.lower() for x in all_graduated_name]
all_retired_name = np.load('./all_retired.npy').tolist()
all_retired = [x.lower() for x in all_retired_name]

# %% [markdown]
# ## Netowork Description
# ### Rewrite Likang's function

# %%
class Technet(object):

    def __init__(self, path):
        self.path = path
        self.get_tech_net()
    

    def get_tech_net(self):

        self.bipartite_G = nx.Graph()
        df = pd.read_csv(self.path, header=None, sep='##', engine='python')
        df.columns = ['file', 'dev', 'weight']

        ## Logic to add nodes and edges to graph with their metadata
        for _, row in df.iterrows():
            dev_node = row['dev']
            file_node = row['file'].replace('   (with props)', '')
            self.bipartite_G.add_node(dev_node, bipartite='dev')
            self.bipartite_G.add_node(file_node, bipartite='file')
            self.bipartite_G.add_edge(dev_node, file_node)
    
        return self

    def stats_tech_net(self):
        # check if file does not exist or empty
        if not os.path.exists(self.path) or os.stat(self.path).st_size == 0:
            return {'t_num_dev_nodes':0,\
                    't_num_file_nodes':0,\
                    't_num_edges': 0,\
                    't_num_dev_per_file':0,\
                    't_num_file_per_dev':0,\
                    't_graph_density':0,\
                    't_dev_nodes': set()}

        self.dev_nodes = {n for n, d in self.bipartite_G.nodes(data=True) if d["bipartite"] == 'dev'}
        self.file_nodes = {n for n, d in self.bipartite_G.nodes(data=True) if d["bipartite"] == 'file'}

        self.graph_density = bipartite.density(self.bipartite_G, self.dev_nodes)
        self.file_degrees, self.dev_degrees = bipartite.degrees(self.bipartite_G, self.dev_nodes)

        self.num_file_nodes = len(self.file_degrees)
        self.num_dev_nodes = len(self.dev_degrees)

        self.file_node_degree = np.average([degree for node, degree in self.file_degrees])
        self.dev_node_degree = np.average([degree for node, degree in self.dev_degrees])

        # return the features of tech net
        return {'t_num_dev_nodes':self.num_dev_nodes,\
                't_num_file_nodes':self.num_file_nodes,\
                't_num_edges': int(self.bipartite_G.size()),\
                't_num_dev_per_file':self.file_node_degree,\
                't_num_file_per_dev':self.dev_node_degree,\
                't_graph_density':self.graph_density,\
                't_dev_nodes': set(self.dev_nodes),\
                't_file_nodes': set(self.file_nodes)}
    
class Socialnet(object):

    def __init__(self, path):
        if os.path.exists(path):
            self.path = path
            self.get_social_net()
        else: 
            raise FileNotFoundError('Edgelist Do not Exist')
            return None
            print("File Not Found")

    
    def get_social_net(self):
        self.G = nx.read_edgelist(self.path, create_using=nx.DiGraph(), nodetype=str, comments='*', delimiter='##', data=(('weight', int),))
        return self.G

    # social nets are weighted
    def stats_social_net(self):
        # if no network data
        if not os.path.exists(self.path) or os.stat(self.path).st_size == 0:
            return {'s_num_nodes':0, \
                    's_dev_nodes':set(),\
                    's_num_edges': 0,\
                    's_weighted_mean_degree':0,\
                    's_num_component':0,\
                    's_avg_clustering_coef':0,\
                    's_largest_component':0,\
                    's_graph_density':0}

        # Processing features in social networks
        #self.G = nx.read_edgelist(self.path, create_using=nx.DiGraph(), nodetype=str, comments='*', delimiter='##', data=(('weight', int),))
        # all dev nodes
        self.dev_nodes = set(self.G.nodes)
        # num. of total nodes
        self.num_nodes = len(self.dev_nodes)
        # weighted mean degree
        self.degrees = self.G.degree(weight='weight')
        self.weighted_mean_degree = np.average([degree for node, degree in self.degrees])
        # average clustering coefficient
        self.avg_clustering_coef = nx.average_clustering(self.G)
        # betweenness = nx.betweenness_centrality(G, weight='weight')
        self.graph_density = nx.density(self.G)

        self.G = nx.read_edgelist(self.path, create_using=nx.Graph(), nodetype=str, comments='*', delimiter='##', data=(('weight', int),))
        # num. of dis-connected components
        self.num_component = nx.number_connected_components(self.G)
        # largest connected component
        self.largest_component = len(max(nx.connected_components(self.G), key=len))
        # num. of nodes in each component
        # num_nodes_component = [list(c) for c in list(nx.connected_components(G))]

        # return the features of the 
        return {'s_num_nodes': self.num_nodes,\
                's_dev_nodes': self.dev_nodes,\
                's_num_edges': int(self.G.size()),\
                's_weighted_mean_degree':self.weighted_mean_degree,\
                's_num_component':self.num_component,\
                's_avg_clustering_coef':self.avg_clustering_coef,\
                's_largest_component':self.largest_component,\
                's_graph_density':self.graph_density}

# %%
class ASFProject(object):

    def __init__(self, projid, the_path):
        self.projid = projid
        self.net_num_limit = 43
        self.time_resolution = 1
        self.c_path = the_path+str(self.time_resolution)+'/commits/'
        self.e_path = the_path+str(self.time_resolution)+'/emails/'
    
    def get_tech_nets(self):
        self.tech_networks = []
        self.tech_network_stats = []
        for seq_num in range(0, self.net_num_limit, self.time_resolution):
            #seq_num = 1
            this_f = self.c_path+self.projid+'__'+str(seq_num)+".edgelist"
            if os.path.exists(this_f):
                this_tnet = Technet(this_f)
                self.tech_networks.append(this_tnet)
                self.tech_network_stats.append(this_tnet.stats_tech_net())
            
                
    def get_social_nets(self):
        self.social_networks = []
        self.social_network_stats = []
        for seq_num in range(0, self.net_num_limit, self.time_resolution):
            #seq_num = 1
            this_f = self.e_path+self.projid+'__'+str(seq_num)+".edgelist"
            if os.path.exists(this_f):
                this_snet = Socialnet(this_f)
                self.social_networks.append(this_snet)
                self.social_network_stats.append(this_snet.stats_social_net())

    def stats_proj_net(self):
        
        return{ 'lifecycle': max(len(self.social_networks),len(self.tech_networks)),\
                't_dev_nodes': [x['t_num_dev_nodes'] for x in self.tech_network_stats],
                't_file_nodes': [x['t_num_file_nodes'] for x in self.tech_network_stats],
                't_edges': [x['t_num_edges'] for x in self.tech_network_stats],
                's_nodes': [x['s_num_nodes'] for x in self.social_network_stats],
                's_edges': [x['s_num_edges'] for x in self.social_network_stats],
                't_num_dev_per_file':[x['t_num_dev_per_file'] for x in self.tech_network_stats],\
                't_num_file_per_dev':[x['t_num_file_per_dev'] for x in self.tech_network_stats]
                }

# %%
import multiprocessing as mp

# %%
def run_proj_stats(projects,q):
    for this_proj in tqdm(projects):
        this_proj.get_tech_nets()
        this_proj.get_social_nets()
        q.put(this_proj.stats_proj_net())    

#def run__process(processnum=6):  # 这里是主进程

# %%
if __name__ == '__main__' :

    the_path = './network_data'
    projects = os.listdir(the_path+"1/commits/")
    projects2 = os.listdir(the_path+"1/emails/")
    project_names = [x.split('__')[0] for x in projects]
    project_names2 = [x.split('__')[0] for x in projects2]
    project_names.extend(project_names2)
    project_freqs = pd.Series(project_names)
    project_names = project_freqs.drop_duplicates().values

    all_projects = {}

    all_proj_stats = {}

    for projid in tqdm(project_names) :
        this_proj = ASFProject(projid, the_path)
        all_projects[projid] = this_proj
    
    all_proj = list(all_projects.values())
    q = mp.Queue()
    process = [mp.Process(target=run_proj_stats, args=(all_proj[:len(all_proj)//6],q)),
               mp.Process(target=run_proj_stats, args=(all_proj[len(all_proj)//6:2*len(all_proj)//6],q)), 
               mp.Process(target=run_proj_stats, args=(all_proj[2*len(all_proj)//6:3*len(all_proj)//6],q)),
               mp.Process(target=run_proj_stats, args=(all_proj[3*len(all_proj)//6:4*len(all_proj)//6],q)),
               mp.Process(target=run_proj_stats, args=(all_proj[4*len(all_proj)//6:5*len(all_proj)//6],q)),
               mp.Process(target=run_proj_stats, args=(all_proj[5*len(all_proj)//6:],q))]
    [p.start() for p in process]  # 开启了两个进程
    [p.join() for p in process]   # 等待两个进程依次结束
    result = [q.get() for proj in all_proj]
# Out:
# 100%|██████████| 275/275 [00:00<00:00, 386409.92it/s]
#   0%|          | 0/45 [00:00<?, ?it/s].63it/s]
# Process Process-1:
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 492, in _infer_columns
#     line = self._buffered_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 584, in _buffered_line
#     return self._next_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 681, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 742, in _next_iter_line
#     return next(self.data)
#   4%|▍         | 2/46 [00:00<00:14,  3.05it/s]StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_31901/4278207062.py", line 3, in run_proj_stats
#     this_proj.get_tech_nets()
#   File "/tmp/ipykernel_31901/874711424.py", line 17, in get_tech_nets
#     this_tnet = Technet(this_f)
#   File "/tmp/ipykernel_31901/3233538825.py", line 5, in __init__
#     self.get_tech_net()
#   File "/tmp/ipykernel_31901/3233538825.py", line 11, in get_tech_net
#     df = pd.read_csv(self.path, header=None, sep='##', engine='python')
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 113, in __init__
#     ) = self._infer_columns()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 496, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#   7%|▋         | 3/46 [00:02<00:30,  1.39it/s]
# Process Process-2:
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 492, in _infer_columns
#     line = self._buffered_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 584, in _buffered_line
#     return self._next_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 681, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 742, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_31901/4278207062.py", line 3, in run_proj_stats
#     this_proj.get_tech_nets()
#   File "/tmp/ipykernel_31901/874711424.py", line 17, in get_tech_nets
#     this_tnet = Technet(this_f)
#   File "/tmp/ipykernel_31901/3233538825.py", line 5, in __init__
#     self.get_tech_net()
#   File "/tmp/ipykernel_31901/3233538825.py", line 11, in get_tech_net
#     df = pd.read_csv(self.path, header=None, sep='##', engine='python')
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 113, in __init__
#     ) = self._infer_columns()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 496, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#   4%|▍         | 2/46 [00:02<00:49,  1.13s/it]
# Process Process-5:
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 492, in _infer_columns
#     line = self._buffered_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 584, in _buffered_line
#     return self._next_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 681, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 742, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_31901/4278207062.py", line 3, in run_proj_stats
#     this_proj.get_tech_nets()
#   File "/tmp/ipykernel_31901/874711424.py", line 17, in get_tech_nets
#     this_tnet = Technet(this_f)
#   File "/tmp/ipykernel_31901/3233538825.py", line 5, in __init__
#     self.get_tech_net()
#   File "/tmp/ipykernel_31901/3233538825.py", line 11, in get_tech_net
#     df = pd.read_csv(self.path, header=None, sep='##', engine='python')
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 113, in __init__
#     ) = self._infer_columns()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 496, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#   9%|▊         | 4/46 [00:02<00:28,  1.49it/s]
# Process Process-3:
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 492, in _infer_columns
#     line = self._buffered_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 584, in _buffered_line
#     return self._next_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 681, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 742, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_31901/4278207062.py", line 3, in run_proj_stats
#     this_proj.get_tech_nets()
#   File "/tmp/ipykernel_31901/874711424.py", line 17, in get_tech_nets
#     this_tnet = Technet(this_f)
#   File "/tmp/ipykernel_31901/3233538825.py", line 5, in __init__
#     self.get_tech_net()
#   File "/tmp/ipykernel_31901/3233538825.py", line 11, in get_tech_net
#     df = pd.read_csv(self.path, header=None, sep='##', engine='python')
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 113, in __init__
#     ) = self._infer_columns()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 496, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#   7%|▋         | 3/46 [00:03<00:53,  1.24s/it]]
# Process Process-4:
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 492, in _infer_columns
#     line = self._buffered_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 584, in _buffered_line
#     return self._next_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 681, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 742, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_31901/4278207062.py", line 3, in run_proj_stats
#     this_proj.get_tech_nets()
#   File "/tmp/ipykernel_31901/874711424.py", line 17, in get_tech_nets
#     this_tnet = Technet(this_f)
#   File "/tmp/ipykernel_31901/3233538825.py", line 5, in __init__
#     self.get_tech_net()
#   File "/tmp/ipykernel_31901/3233538825.py", line 11, in get_tech_net
#     df = pd.read_csv(self.path, header=None, sep='##', engine='python')
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 113, in __init__
#     ) = self._infer_columns()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 496, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#  37%|███▋      | 17/46 [00:05<00:08,  3.36it/s]
# Process Process-6:
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 492, in _infer_columns
#     line = self._buffered_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 584, in _buffered_line
#     return self._next_line()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 681, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 742, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_31901/4278207062.py", line 3, in run_proj_stats
#     this_proj.get_tech_nets()
#   File "/tmp/ipykernel_31901/874711424.py", line 17, in get_tech_nets
#     this_tnet = Technet(this_f)
#   File "/tmp/ipykernel_31901/3233538825.py", line 5, in __init__
#     self.get_tech_net()
#   File "/tmp/ipykernel_31901/3233538825.py", line 11, in get_tech_net
#     df = pd.read_csv(self.path, header=None, sep='##', engine='python')
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 113, in __init__
#     ) = self._infer_columns()
#   File "/home/wsl2forwin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/io/parsers/python_parser.py", line 496, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_31901/2669155682.py in <module>
#      28     [p.start() for p in process]  # 开启了两个进程
#      29     [p.join() for p in process]   # 等待两个进程依次结束
# ---> 30     result = [q.get() for proj in all_proj]
#      31
#
# /tmp/ipykernel_31901/2669155682.py in <listcomp>(.0)
#      28     [p.start() for p in process]  # 开启了两个进程
#      29     [p.join() for p in process]   # 等待两个进程依次结束
# ---> 30     result = [q.get() for proj in all_proj]
#      31
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/queues.py in get(self, block, timeout)
#      95         if block and timeout is None:
#      96             with self._rlock:
# ---> 97                 res = self._recv_bytes()
#      98             self._sem.release()
#      99         else:
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     412
#     413     def _recv_bytes(self, maxsize=None):
# --> 414         buf = self._recv(4)
#     415         size, = struct.unpack("!i", buf.getvalue())
#     416         if size == -1:
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

# %%
project_names2
# Out:
# ['edgent',
#  'hdt',
#  'mnemonic',
#  'juneau',
#  'odf',
#  'taverna',
#  'zeta',
#  'streams',
#  'oozie',
#  'roller',
#  'odf',
#  'nuvem',
#  'synapse',
#  'griffin',
#  'guacamole',
#  'wave',
#  'kalumet',
#  'jackrabbit',
#  'wink',
#  'deltacloud',
#  'batchee',
#  'apex',
#  'falcon',
#  'eagle',
#  'odf',
#  'roller',
#  'hawq',
#  'esme',
#  'provisionr',
#  'gora',
#  'twill',
#  'sling',
#  'pulsar',
#  'quickstep',
#  'batchee',
#  'wink',
#  'ignite',
#  'flex',
#  'juneau',
#  'photark',
#  'tamaya',
#  'omid',
#  'gora',
#  'tashi',
#  's4',
#  'phoenix',
#  'river',
#  'sis',
#  'myriad',
#  'ode',
#  'samoa',
#  'empire',
#  'singa',
#  'phoenix',
#  'river',
#  'datafu',
#  'echarts',
#  'oltu',
#  'predictionio',
#  'kafka',
#  'datafu',
#  'juneau',
#  'openwhisk',
#  'slider',
#  'directory',
#  'madlib',
#  'sling',
#  'olio',
#  'streams',
#  'weex',
#  'ftpserver',
#  'derby',
#  'aurora',
#  'superset',
#  'nuvem',
#  'plc4x',
#  'openmeetings',
#  'river',
#  'pirk',
#  'clerezza',
#  'olio',
#  'wink',
#  'trafficcontrol',
#  'empire',
#  'oltu',
#  'usergrid',
#  'ctakes',
#  'manifoldcf',
#  'quickstep',
#  'netbeans',
#  'directory',
#  'jspwiki',
#  'slider',
#  'mesos',
#  'subversion',
#  'river',
#  'clerezza',
#  'celix',
#  'socialsite',
#  'plc4x',
#  'netbeans',
#  'dubbo',
#  'airflow',
#  'nutch',
#  'edgent',
#  'atlas',
#  'omid',
#  'hama',
#  'batchee',
#  'tashi',
#  'droids',
#  'river',
#  'synapse',
#  'tika',
#  'zipkin',
#  'bluesky',
#  'predictionio',
#  'slider',
#  'felix',
#  'trafficcontrol',
#  'horn',
#  'datafu',
#  'river',
#  'calcite',
#  'edgent',
#  'npanday',
#  'griffin',
#  'kalumet',
#  'singa',
#  'heraldry',
#  'pirk',
#  'skywalking',
#  'hcatalog',
#  'pinot',
#  'odf',
#  'wave',
#  's2graph',
#  'tika',
#  'blur',
#  's2graph',
#  'graffito',
#  'ranger',
#  'xap',
#  'mesos',
#  'etch',
#  'wookie',
#  'xap',
#  'abdera',
#  'jspwiki',
#  'corinthia',
#  'qpid',
#  'droids',
#  'singa',
#  'droids',
#  'npanday',
#  'odf',
#  'hama',
#  'bookkeeper',
#  'wink',
#  'storm',
#  'streams',
#  'taverna',
#  'mesos',
#  'spamassassin',
#  'graffito',
#  'freemarker',
#  'servicemix',
#  'sentry',
#  'thrift',
#  'zeta',
#  'lokahi',
#  'etch',
#  'guacamole',
#  'mnemonic',
#  'isis',
#  'hama',
#  'blur',
#  'htrace',
#  'omid',
#  'hcatalog',
#  'guacamole',
#  'sis',
#  'tez',
#  'johnzon',
#  'droids',
#  'unomi',
#  'zeta',
#  'bookkeeper',
#  'celix',
#  'uima',
#  'airavata',
#  'pulsar',
#  'clerezza',
#  'odf',
#  'opennlp',
#  'allura',
#  'wave',
#  'trafficcontrol',
#  'hise',
#  'sirona',
#  'odf',
#  'skywalking',
#  'systemml',
#  'harmony',
#  'xmlbeans',
#  'npanday',
#  'netbeans',
#  'quickstep',
#  'samza',
#  'ripple',
#  'ftpserver',
#  'dolphinscheduler',
#  'sanselan',
#  'sling',
#  'kato',
#  'openwhisk',
#  'echarts',
#  'echarts',
#  'openmeetings',
#  'deltacloud',
#  'quickstep',
#  'hawq',
#  'fineract',
#  'aurora',
#  'kudu',
#  'bloodhound',
#  'mod_ftp',
#  'blur',
#  'aries',
#  'tinkerpop',
#  'shindig',
#  'lucenenet',
#  'ace',
#  'fineract',
#  'flex',
#  'celix',
#  'wave',
#  'rocketmq',
#  'triplesoup',
#  'oltu',
#  'heraldry',
#  'taverna',
#  'batchee',
#  's2graph',
#  'accumulo',
#  'wave',
#  's4',
#  'bval',
#  'blur',
#  'impala',
#  'celix',
#  'datafu',
#  'depot',
#  'npanday',
#  'bluesky',
#  'freemarker',
#  'rcf',
#  'beehive',
#  'impala',
#  'openaz',
#  'tashi',
#  'superset',
#  'weex',
#  'aurora',
#  'metron',
#  'helix',
#  'isis',
#  'stanbol',
#  'batchee',
#  'kitty',
#  'kitty',
#  'jspwiki',
#  'cmda',
#  'samza',
#  'openmeetings',
#  'yoko',
#  'daffodil',
#  'alois',
#  'quickstep',
#  'htrace',
#  'zeta',
#  'sqoop',
#  'systemml',
#  'datafu',
#  'pulsar',
#  'datafu',
#  'sling',
#  'juice',
#  'rya',
#  'batchee',
#  'wave',
#  'trafodion',
#  'rya',
#  'ftpserver',
#  'htrace',
#  'ivy',
#  'bookkeeper',
#  'myriad',
#  'wicket',
#  'batchee',
#  'vxquery',
#  's2graph',
#  'heraldry',
#  'tephra',
#  'chemistry',
#  'chukwa',
#  'jspwiki',
#  'ftpserver',
#  'manifoldcf',
#  'helix',
#  'taverna',
#  'gearpump',
#  'bluesky',
#  'empire',
#  'uima',
#  'taverna',
#  'iotdb',
#  'edgent',
#  'ibatis',
#  'ace',
#  'openwhisk',
#  'manifoldcf',
#  'ode',
#  'etch',
#  'roller',
#  'echarts',
#  'etch',
#  'felix',
#  'tamaya',
#  'mrql',
#  'wink',
#  'qpid',
#  'lucy',
#  'vxquery',
#  'activemq',
#  'tamaya',
#  'streams',
#  'olio',
#  'sis',
#  'bval',
#  'wave',
#  'manifoldcf',
#  'joshua',
#  'iceberg',
#  'brooklyn',
#  'ignite',
#  'iota',
#  's2graph',
#  'flume',
#  'cmda',
#  'sanselan',
#  'hawq',
#  'droids',
#  'wave',
#  'kalumet',
#  'lokahi',
#  'rave',
#  'taverna',
#  'lucy',
#  'shindig',
#  'yoko',
#  'awf',
#  'syncope',
#  'sis',
#  'tephra',
#  'batchee',
#  'datafu',
#  'bigtop',
#  'samoa',
#  'iota',
#  'qpid',
#  'marmotta',
#  'odf',
#  'gobblin',
#  'wookie',
#  'hama',
#  'reef',
#  'taverna',
#  'libcloud',
#  'hise',
#  'guacamole',
#  'hawq',
#  'sqoop',
#  'lucy',
#  'gossip',
#  'johnzon',
#  'ranger',
#  'kitty',
#  'celix',
#  'madlib',
#  'calcite',
#  'streams',
#  'tez',
#  'sirona',
#  'superset',
#  'xap',
#  'druid',
#  'geode',
#  'rya',
#  'photark',
#  'openwebbeans',
#  'qpid',
#  'manifoldcf',
#  'thrift',
#  'heraldry',
#  's2graph',
#  'plc4x',
#  'kylin',
#  'kitty',
#  'fluo',
#  'cayenne',
#  'dolphinscheduler',
#  'shiro',
#  'wave',
#  'hudi',
#  'openoffice',
#  'slider',
#  'apex',
#  'knox',
#  'olingo',
#  'graffito',
#  'libcloud',
#  'asterixdb',
#  'shindig',
#  'samoa',
#  'ivy',
#  'shardingsphere',
#  'tephra',
#  'streams',
#  'tashi',
#  'couchdb',
#  'pinot',
#  'etch',
#  'gearpump',
#  'graffito',
#  'bluesky',
#  'allura',
#  'taverna',
#  'etch',
#  'bluesky',
#  'devicemap',
#  'tvm',
#  'giraph',
#  'ftpserver',
#  'pinot',
#  'droids',
#  'hawq',
#  'kitty',
#  'pdfbox',
#  'ace',
#  'batchee',
#  'flink',
#  'kitty',
#  'bloodhound',
#  'parquet',
#  'drill',
#  'tamaya',
#  'singa',
#  'sirona',
#  's2graph',
#  'daffodil',
#  'tephra',
#  'felix',
#  'tinkerpop',
#  'olio',
#  'vcl',
#  'airavata',
#  'kato',
#  'triplesoup',
#  'oodt',
#  'mrunit',
#  'airflow',
#  'ratis',
#  'trafficcontrol',
#  'openwhisk',
#  'weex',
#  'superset',
#  'curator',
#  'isis',
#  'trafficcontrol',
#  'wink',
#  'fineract',
#  'mnemonic',
#  'impala',
#  'allura',
#  'jspwiki',
#  'roller',
#  'asterixdb',
#  'flink',
#  'amaterasu',
#  'mrunit',
#  'bookkeeper',
#  'oltu',
#  'vcl',
#  'couchdb',
#  'samoa',
#  'tinkerpop',
#  'blur',
#  'odf',
#  'omid',
#  'aurora',
#  'quickstep',
#  'odf',
#  'trafficcontrol',
#  'airavata',
#  'openwhisk',
#  'kylin',
#  'curator',
#  'buildr',
#  'trafodion',
#  'weex',
#  'pdfbox',
#  'juice',
#  'systemml',
#  'metron',
#  'droids',
#  'photark',
#  'samza',
#  'hama',
#  'datasketches',
#  'ratis',
#  'taverna',
#  'iotdb',
#  'servicecomb',
#  'tuscany',
#  'streams',
#  'clerezza',
#  'syncope',
#  'trafodion',
#  'cayenne',
#  'superset',
#  'vxquery',
#  'openjpa',
#  'heraldry',
#  'wave',
#  'wink',
#  'graffito',
#  'tuscany',
#  'slider',
#  'omid',
#  'jackrabbit',
#  'singa',
#  'activemq',
#  'ant',
#  'nifi',
#  'drill',
#  'uima',
#  'edgent',
#  'zipkin',
#  'celix',
#  'slider',
#  'twill',
#  'falcon',
#  'omid',
#  'openoffice',
#  'beehive',
#  'wave',
#  'allura',
#  'thrift',
#  'ivy',
#  'myriad',
#  'kalumet',
#  'zeta',
#  'devicemap',
#  'tamaya',
#  'wink',
#  'esme',
#  'jena',
#  'commonsrdf',
#  'kylin',
#  'bluesky',
#  'edgent',
#  'nuvem',
#  'gossip',
#  'climate',
#  'celix',
#  'alois',
#  'curator',
#  'taverna',
#  'taverna',
#  'deltaspike',
#  'iotdb',
#  'usergrid',
#  'gobblin',
#  'htrace',
#  'mynewt',
#  'devicemap',
#  'wave',
#  'tashi',
#  'abdera',
#  'derby',
#  'sentry',
#  'nmaven',
#  'npanday',
#  'wave',
#  'batchee',
#  'openaz',
#  'agila',
#  'olio',
#  'edgent',
#  'manifoldcf',
#  'pivot',
#  'cotton',
#  'singa',
#  'etch',
#  'samoa',
#  'rcf',
#  'mrql',
#  'samoa',
#  'etch',
#  'kalumet',
#  'bluesky',
#  'etch',
#  'vxquery',
#  'olio',
#  'warble',
#  'falcon',
#  'ratis',
#  'helix',
#  'taverna',
#  'sanselan',
#  'batchee',
#  'samoa',
#  'yoko',
#  'beam',
#  'daffodil',
#  'tashi',
#  'rocketmq',
#  'buildr',
#  'pivot',
#  'dolphinscheduler',
#  'griffin',
#  'daffodil',
#  'impala',
#  'vcl',
#  'vcl',
#  'stratos',
#  'ctakes',
#  'sanselan',
#  'tuscany',
#  'jspwiki',
#  'rya',
#  'graffito',
#  'lucy',
#  'mrql',
#  'libcloud',
#  'spark',
#  'tika',
#  's2graph',
#  'allura',
#  'thrift',
#  'pirk',
#  'rocketmq',
#  'marmotta',
#  'etch',
#  'marmotta',
#  'cordova',
#  'wink',
#  'freemarker',
#  'weex',
#  'wookie',
#  'opennlp',
#  'wookie',
#  'odf',
#  'unomi',
#  'yoko',
#  'hudi',
#  'knox',
#  'samza',
#  'zeppelin',
#  'wookie',
#  'hawq',
#  'slider',
#  'uima',
#  'odf',
#  'ariatosca',
#  'jspwiki',
#  'systemml',
#  'xap',
#  'unomi',
#  'parquet',
#  'daffodil',
#  'ant',
#  'hawq',
#  'druid',
#  'esme',
#  'datafu',
#  'stanbol',
#  'shardingsphere',
#  'lucenenet',
#  'isis',
#  'johnzon',
#  'brooklyn',
#  'sentry',
#  'tamaya',
#  'kalumet',
#  'vxquery',
#  'echarts',
#  'ratis',
#  'gearpump',
#  'slider',
#  'blur',
#  'servicecomb',
#  'rya',
#  'jspwiki',
#  'parquet',
#  'olio',
#  'mrql',
#  'sirona',
#  'hawq',
#  'datafu',
#  'npanday',
#  'tamaya',
#  'jackrabbit',
#  'carbondata',
#  'vcl',
#  'agila',
#  'odf',
#  'abdera',
#  'ripple',
#  'beehive',
#  'shardingsphere',
#  'openwebbeans',
#  'triplesoup',
#  'sis',
#  'amaterasu',
#  'taverna',
#  'celix',
#  'npanday',
#  'imperius',
#  'hawq',
#  'streams',
#  'odf',
#  'ace',
#  'daffodil',
#  'tamaya',
#  'droids',
#  'vcl',
#  'lokahi',
#  'cloudstack',
#  'imperius',
#  'vxquery',
#  'ripple',
#  'netbeans',
#  'chukwa',
#  'openwhisk',
#  'muse',
#  'cassandra',
#  'aurora',
#  'knox',
#  'felix',
#  'mrql',
#  'olio',
#  'commonsrdf',
#  'hawq',
#  'juice',
#  'weex',
#  'jspwiki',
#  'joshua',
#  'openwebbeans',
#  'crunch',
#  'atlas',
#  'oltu',
#  'batchee',
#  'tajo',
#  'cmda',
#  'trafficserver',
#  'beam',
#  'netbeans',
#  'mod_ftp',
#  'activemq',
#  'mrql',
#  'sling',
#  'jena',
#  'jspwiki',
#  'uima',
#  'impala',
#  'iotdb',
#  'airflow',
#  's2graph',
#  'servicemix',
#  'bigtop',
#  'falcon',
#  'concerted',
#  'edgent',
#  'blur',
#  'openoffice',
#  'weex',
#  'openoffice',
#  'sirona',
#  'uima',
#  'river',
#  'systemml',
#  'tuscany',
#  'nmaven',
#  'provisionr',
#  'gobblin',
#  'shiro',
#  'ace',
#  'flex',
#  'groovy',
#  'climate',
#  'edgent',
#  'netbeans',
#  'bluesky',
#  'iota',
#  'superset',
#  'tez',
#  'stonehenge',
#  'sis',
#  'kudu',
#  'uima',
#  'hawq',
#  'quickstep',
#  'apisix',
#  'wookie',
#  'ratis',
#  'any23',
#  'trafficserver',
#  'esme',
#  'sanselan',
#  'jdo',
#  'droids',
#  'directory',
#  'ranger',
#  'madlib',
#  'hcatalog',
#  'pivot',
#  'warble',
#  'horn',
#  'horn',
#  'river',
#  'kitty',
#  'rya',
#  'mesos',
#  'streams',
#  'unomi',
#  'uima',
#  'gossip',
#  'pdfbox',
#  'sirona',
#  'openmeetings',
#  'datafu',
#  'myriad',
#  'deltaspike',
#  'amaterasu',
#  'wave',
#  'ratis',
#  'joshua',
#  'iota',
#  'myriad',
#  'plc4x',
#  'hawq',
#  'hama',
#  'awf',
#  'graffito',
#  'stdcxx',
#  'tika',
#  'mrql',
#  'empire',
#  'batchee',
#  'openwebbeans',
#  'corinthia',
#  'sanselan',
#  'giraph',
#  'imperius',
#  'mrunit',
#  'streams',
#  'shiro',
#  'gossip',
#  'slider',
#  'thrift',
#  'kato',
#  'tamaya',
#  'edgent',
#  'joshua',
#  'madlib',
#  'dolphinscheduler',
#  'tephra',
#  'hdt',
#  'cxf',
#  'sirona',
#  'joshua',
#  'singa',
#  'omid',
#  'ofbiz',
#  'samza',
#  'datafu',
#  'awf',
#  'vcl',
#  'myriad',
#  'onami',
#  'samoa',
#  'kalumet',
#  'bluesky',
#  'predictionio',
#  'madlib',
#  'wave',
#  'chukwa',
#  'jdo',
#  'celix',
#  'wookie',
#  'wave',
#  'ivy',
#  'mrql',
#  'odf',
#  'jena',
#  'ftpserver',
#  'tuscany',
#  'predictionio',
#  'stonehenge',
#  'droids',
#  'river',
#  'bluesky',
#  'pivot',
#  'slider',
#  'xap',
#  'tashi',
#  'drill',
#  'etch',
#  'pig',
#  'vxquery',
#  'ranger',
#  'triplesoup',
#  'deltacloud',
#  'htrace',
#  'ode',
#  'giraph',
#  'thrift',
#  'uima',
#  'river',
#  'drill',
#  'empire',
#  'empire',
#  'mod_ftp',
#  'wave',
#  'hama',
#  'usergrid',
#  'droids',
#  'iotdb',
#  'vxquery',
#  'graffito',
#  'deltaspike',
#  'lokahi',
#  'datasketches',
#  'ripple',
#  'wave',
#  'chemistry',
#  'droids',
#  'dubbo',
#  'devicemap',
#  'ranger',
#  'superset',
#  'iota',
#  'uima',
#  'tashi',
#  'trafodion',
#  'sling',
#  'johnzon',
#  'hdt',
#  'stdcxx',
#  'ode',
#  'batchee',
#  'solr',
#  'cassandra',
#  'qpid',
#  'storm',
#  'solr',
#  'kato',
#  'weex',
#  'activemq',
#  'apex',
#  'gossip',
#  'druid',
#  'reef',
#  'openwhisk',
#  'datafu',
#  'rave',
#  'hcatalog',
#  'lucy',
#  'tvm',
#  'wink',
#  's4',
#  'joshua',
#  'metron',
#  'druid',
#  'ariatosca',
#  'quickstep',
#  'hama',
#  'sanselan',
#  'tika',
#  'drill',
#  'celix',
#  'geronimo',
#  'rya',
#  'johnzon',
#  'horn',
#  'sis',
#  'kafka',
#  'bval',
#  ...]

# %%
all_projects['odf'].get_tech_nets()
all_projects['odf'].get_social_nets()
all_projects['odf'].stats_proj_net()
# Out:
# {'lifecycle': 0,
#  't_dev_nodes': [],
#  't_file_nodes': [],
#  't_edges': [],
#  's_nodes': [],
#  's_edges': [],
#  't_num_dev_per_file': [],
#  't_num_file_per_dev': []}

# %%
all_projects['odf'].c_path
# Out:
# './network_data1/commits/1/commits/'

# %%
all_proj
# Out:
# [<__main__.ASFProject at 0x7f55c3f845b0>,
#  <__main__.ASFProject at 0x7f55c3f84610>,
#  <__main__.ASFProject at 0x7f55c3f845e0>,
#  <__main__.ASFProject at 0x7f55c3f84640>,
#  <__main__.ASFProject at 0x7f55c3f84340>,
#  <__main__.ASFProject at 0x7f55c3f84790>,
#  <__main__.ASFProject at 0x7f55c3f84220>,
#  <__main__.ASFProject at 0x7f55c3f84a90>,
#  <__main__.ASFProject at 0x7f55c3f84af0>,
#  <__main__.ASFProject at 0x7f55c3f84700>,
#  <__main__.ASFProject at 0x7f55c3f84c40>,
#  <__main__.ASFProject at 0x7f55c3f84400>,
#  <__main__.ASFProject at 0x7f55c3f84430>,
#  <__main__.ASFProject at 0x7f55c3f84d90>,
#  <__main__.ASFProject at 0x7f55c3f84190>,
#  <__main__.ASFProject at 0x7f55c3f84e80>,
#  <__main__.ASFProject at 0x7f55c3f84f40>,
#  <__main__.ASFProject at 0x7f55c3f84f70>,
#  <__main__.ASFProject at 0x7f55c3f84f10>,
#  <__main__.ASFProject at 0x7f55c3f84ca0>,
#  <__main__.ASFProject at 0x7f55c3f84dc0>,
#  <__main__.ASFProject at 0x7f55c3f84ee0>,
#  <__main__.ASFProject at 0x7f55a2d46070>,
#  <__main__.ASFProject at 0x7f55a2d460d0>,
#  <__main__.ASFProject at 0x7f55a2d46130>,
#  <__main__.ASFProject at 0x7f55a2d46190>,
#  <__main__.ASFProject at 0x7f55a2d461f0>,
#  <__main__.ASFProject at 0x7f55a2d46250>,
#  <__main__.ASFProject at 0x7f55a2d462b0>,
#  <__main__.ASFProject at 0x7f55a2d46310>,
#  <__main__.ASFProject at 0x7f55a2d46370>,
#  <__main__.ASFProject at 0x7f55a2d463d0>,
#  <__main__.ASFProject at 0x7f55a2d46430>,
#  <__main__.ASFProject at 0x7f55a2d46490>,
#  <__main__.ASFProject at 0x7f55a2d464f0>,
#  <__main__.ASFProject at 0x7f55a2d46550>,
#  <__main__.ASFProject at 0x7f55a2d465b0>,
#  <__main__.ASFProject at 0x7f55a2d46610>,
#  <__main__.ASFProject at 0x7f55a2d46670>,
#  <__main__.ASFProject at 0x7f55a2d466d0>,
#  <__main__.ASFProject at 0x7f55a2d46730>,
#  <__main__.ASFProject at 0x7f55a2d46790>,
#  <__main__.ASFProject at 0x7f55a2d467f0>,
#  <__main__.ASFProject at 0x7f55a2d46850>,
#  <__main__.ASFProject at 0x7f55a2d468b0>,
#  <__main__.ASFProject at 0x7f55a2d46910>,
#  <__main__.ASFProject at 0x7f55a2d46970>,
#  <__main__.ASFProject at 0x7f55a2d469d0>,
#  <__main__.ASFProject at 0x7f55a2d46a30>,
#  <__main__.ASFProject at 0x7f55a2d46a90>,
#  <__main__.ASFProject at 0x7f55a2d46af0>,
#  <__main__.ASFProject at 0x7f55a2d46b50>,
#  <__main__.ASFProject at 0x7f55a2d46bb0>,
#  <__main__.ASFProject at 0x7f55a2d46c10>,
#  <__main__.ASFProject at 0x7f55a2d46c70>,
#  <__main__.ASFProject at 0x7f55a2d46cd0>,
#  <__main__.ASFProject at 0x7f55a2d46d30>,
#  <__main__.ASFProject at 0x7f55a2d46d90>,
#  <__main__.ASFProject at 0x7f55a2d46df0>,
#  <__main__.ASFProject at 0x7f55a2d46e50>,
#  <__main__.ASFProject at 0x7f55a2d46eb0>,
#  <__main__.ASFProject at 0x7f55a2d46f10>,
#  <__main__.ASFProject at 0x7f55a2d46f70>,
#  <__main__.ASFProject at 0x7f55a2d46fd0>,
#  <__main__.ASFProject at 0x7f55a2d43070>,
#  <__main__.ASFProject at 0x7f55a2d430d0>,
#  <__main__.ASFProject at 0x7f55a2d43130>,
#  <__main__.ASFProject at 0x7f55a2d43190>,
#  <__main__.ASFProject at 0x7f55a2d431f0>,
#  <__main__.ASFProject at 0x7f55a2d43250>,
#  <__main__.ASFProject at 0x7f55a2d432b0>,
#  <__main__.ASFProject at 0x7f55a2d43310>,
#  <__main__.ASFProject at 0x7f55a2d43370>,
#  <__main__.ASFProject at 0x7f55a2d433d0>,
#  <__main__.ASFProject at 0x7f55a2d43430>,
#  <__main__.ASFProject at 0x7f55a2d43490>,
#  <__main__.ASFProject at 0x7f55a2d434f0>,
#  <__main__.ASFProject at 0x7f55a2d43550>,
#  <__main__.ASFProject at 0x7f55a2d435b0>,
#  <__main__.ASFProject at 0x7f55a2d43610>,
#  <__main__.ASFProject at 0x7f55a2d43670>,
#  <__main__.ASFProject at 0x7f55a2d436d0>,
#  <__main__.ASFProject at 0x7f55a2d43730>,
#  <__main__.ASFProject at 0x7f55a2d43790>,
#  <__main__.ASFProject at 0x7f55a2d437f0>,
#  <__main__.ASFProject at 0x7f55a2d43850>,
#  <__main__.ASFProject at 0x7f55a2d438b0>,
#  <__main__.ASFProject at 0x7f55a2d43910>,
#  <__main__.ASFProject at 0x7f55a2d43970>,
#  <__main__.ASFProject at 0x7f55a2d439d0>,
#  <__main__.ASFProject at 0x7f55a2d43a30>,
#  <__main__.ASFProject at 0x7f55a2d43a90>,
#  <__main__.ASFProject at 0x7f55a2d43af0>,
#  <__main__.ASFProject at 0x7f55a2d43b50>,
#  <__main__.ASFProject at 0x7f55a2d43bb0>,
#  <__main__.ASFProject at 0x7f55a2d43c10>,
#  <__main__.ASFProject at 0x7f55a2d43c70>,
#  <__main__.ASFProject at 0x7f55a2d43cd0>,
#  <__main__.ASFProject at 0x7f55a2d43d30>,
#  <__main__.ASFProject at 0x7f55a2d43d90>,
#  <__main__.ASFProject at 0x7f55a2d43df0>,
#  <__main__.ASFProject at 0x7f55a2d43e50>,
#  <__main__.ASFProject at 0x7f55a2d43eb0>,
#  <__main__.ASFProject at 0x7f55a2d43f10>,
#  <__main__.ASFProject at 0x7f55a2d43f70>,
#  <__main__.ASFProject at 0x7f55a2d43fd0>,
#  <__main__.ASFProject at 0x7f55a2d3c070>,
#  <__main__.ASFProject at 0x7f55a2d3c0d0>,
#  <__main__.ASFProject at 0x7f55a2d3c130>,
#  <__main__.ASFProject at 0x7f55a2d3c190>,
#  <__main__.ASFProject at 0x7f55a2d3c1f0>,
#  <__main__.ASFProject at 0x7f55a2d3c250>,
#  <__main__.ASFProject at 0x7f55a2d3c2b0>,
#  <__main__.ASFProject at 0x7f55a2d3c310>,
#  <__main__.ASFProject at 0x7f55a2d3c370>,
#  <__main__.ASFProject at 0x7f55a2d3c3d0>,
#  <__main__.ASFProject at 0x7f55a2d3c430>,
#  <__main__.ASFProject at 0x7f55a2d3c490>,
#  <__main__.ASFProject at 0x7f55a2d3c4f0>,
#  <__main__.ASFProject at 0x7f55a2d3c550>,
#  <__main__.ASFProject at 0x7f55a2d3c5b0>,
#  <__main__.ASFProject at 0x7f55a2d3c610>,
#  <__main__.ASFProject at 0x7f55a2d3c670>,
#  <__main__.ASFProject at 0x7f55a2d3c6d0>,
#  <__main__.ASFProject at 0x7f55a2d3c730>,
#  <__main__.ASFProject at 0x7f55a2d3c790>,
#  <__main__.ASFProject at 0x7f55a2d3c7f0>,
#  <__main__.ASFProject at 0x7f55a2d3c850>,
#  <__main__.ASFProject at 0x7f55a2d3c8b0>,
#  <__main__.ASFProject at 0x7f55a2d3c910>,
#  <__main__.ASFProject at 0x7f55a2d3c970>,
#  <__main__.ASFProject at 0x7f55a2d3c9d0>,
#  <__main__.ASFProject at 0x7f55a2d3ca30>,
#  <__main__.ASFProject at 0x7f55a2d3ca90>,
#  <__main__.ASFProject at 0x7f55a2d3caf0>,
#  <__main__.ASFProject at 0x7f55a2d3cb50>,
#  <__main__.ASFProject at 0x7f55a2d3cbb0>,
#  <__main__.ASFProject at 0x7f55a2d3cc10>,
#  <__main__.ASFProject at 0x7f55a2d3cc70>,
#  <__main__.ASFProject at 0x7f55a2d3ccd0>,
#  <__main__.ASFProject at 0x7f55a2d3cd30>,
#  <__main__.ASFProject at 0x7f55a2d3cd90>,
#  <__main__.ASFProject at 0x7f55a2d3cdf0>,
#  <__main__.ASFProject at 0x7f55a2d3ce50>,
#  <__main__.ASFProject at 0x7f55a2d3ceb0>,
#  <__main__.ASFProject at 0x7f55a2d3cf10>,
#  <__main__.ASFProject at 0x7f55a2d3cf70>,
#  <__main__.ASFProject at 0x7f55a2d3cfd0>,
#  <__main__.ASFProject at 0x7f55c3f23070>,
#  <__main__.ASFProject at 0x7f55c3f230d0>,
#  <__main__.ASFProject at 0x7f55c3f23130>,
#  <__main__.ASFProject at 0x7f55c3f23190>,
#  <__main__.ASFProject at 0x7f55c3f231f0>,
#  <__main__.ASFProject at 0x7f55c3f23250>,
#  <__main__.ASFProject at 0x7f55c3f232b0>,
#  <__main__.ASFProject at 0x7f55c3f23310>,
#  <__main__.ASFProject at 0x7f55c3f23370>,
#  <__main__.ASFProject at 0x7f55c3f233d0>,
#  <__main__.ASFProject at 0x7f55c3f23430>,
#  <__main__.ASFProject at 0x7f55c3f23490>,
#  <__main__.ASFProject at 0x7f55c3f234f0>,
#  <__main__.ASFProject at 0x7f55c3f23550>,
#  <__main__.ASFProject at 0x7f55c3f235b0>,
#  <__main__.ASFProject at 0x7f55c3f23610>,
#  <__main__.ASFProject at 0x7f55c3f23670>,
#  <__main__.ASFProject at 0x7f55c3f236d0>,
#  <__main__.ASFProject at 0x7f55c3f23730>,
#  <__main__.ASFProject at 0x7f55c3f23790>,
#  <__main__.ASFProject at 0x7f55c3f237f0>,
#  <__main__.ASFProject at 0x7f55c3f23850>,
#  <__main__.ASFProject at 0x7f55c3f238b0>,
#  <__main__.ASFProject at 0x7f55c3f23910>,
#  <__main__.ASFProject at 0x7f55c3f23970>,
#  <__main__.ASFProject at 0x7f55c3f239d0>,
#  <__main__.ASFProject at 0x7f55c3f23a30>,
#  <__main__.ASFProject at 0x7f55c3f23a90>,
#  <__main__.ASFProject at 0x7f55c3f23af0>,
#  <__main__.ASFProject at 0x7f55c3f23b50>,
#  <__main__.ASFProject at 0x7f55c3f23bb0>,
#  <__main__.ASFProject at 0x7f55c3f23c10>,
#  <__main__.ASFProject at 0x7f55c3f23c70>,
#  <__main__.ASFProject at 0x7f55c3f23cd0>,
#  <__main__.ASFProject at 0x7f55c3f23d30>,
#  <__main__.ASFProject at 0x7f55c3f23d90>,
#  <__main__.ASFProject at 0x7f55c3f23df0>,
#  <__main__.ASFProject at 0x7f55c3f23e50>,
#  <__main__.ASFProject at 0x7f55c3f23eb0>,
#  <__main__.ASFProject at 0x7f55c3f23f10>,
#  <__main__.ASFProject at 0x7f55c3f23f70>,
#  <__main__.ASFProject at 0x7f55c3f23fd0>,
#  <__main__.ASFProject at 0x7f55c3f26070>,
#  <__main__.ASFProject at 0x7f55c3f260d0>,
#  <__main__.ASFProject at 0x7f55c3f26130>,
#  <__main__.ASFProject at 0x7f55c3f26190>,
#  <__main__.ASFProject at 0x7f55c3f261f0>,
#  <__main__.ASFProject at 0x7f55c3f26250>,
#  <__main__.ASFProject at 0x7f55c3f262b0>,
#  <__main__.ASFProject at 0x7f55c3f26310>,
#  <__main__.ASFProject at 0x7f55c3f26370>,
#  <__main__.ASFProject at 0x7f55c3f263d0>,
#  <__main__.ASFProject at 0x7f55c3f26430>,
#  <__main__.ASFProject at 0x7f55c3f26490>,
#  <__main__.ASFProject at 0x7f55c3f264f0>,
#  <__main__.ASFProject at 0x7f55c3f26550>,
#  <__main__.ASFProject at 0x7f55c3f265b0>,
#  <__main__.ASFProject at 0x7f55c3f26610>,
#  <__main__.ASFProject at 0x7f55c3f26670>,
#  <__main__.ASFProject at 0x7f55c3f266d0>,
#  <__main__.ASFProject at 0x7f55c3f26730>,
#  <__main__.ASFProject at 0x7f55c3f26790>,
#  <__main__.ASFProject at 0x7f55c3f267f0>,
#  <__main__.ASFProject at 0x7f55c3f26850>,
#  <__main__.ASFProject at 0x7f55c3f268b0>,
#  <__main__.ASFProject at 0x7f55c3f26910>,
#  <__main__.ASFProject at 0x7f55c3f26970>,
#  <__main__.ASFProject at 0x7f55c3f269d0>,
#  <__main__.ASFProject at 0x7f55c3f26a30>,
#  <__main__.ASFProject at 0x7f55c3f26a90>,
#  <__main__.ASFProject at 0x7f55c3f26af0>,
#  <__main__.ASFProject at 0x7f55c3f26b50>,
#  <__main__.ASFProject at 0x7f55c3f26bb0>,
#  <__main__.ASFProject at 0x7f55c3f26c10>,
#  <__main__.ASFProject at 0x7f55c3f26c70>,
#  <__main__.ASFProject at 0x7f55c3f26cd0>,
#  <__main__.ASFProject at 0x7f55c3f26d30>,
#  <__main__.ASFProject at 0x7f55c3f26d90>,
#  <__main__.ASFProject at 0x7f55c3f26df0>,
#  <__main__.ASFProject at 0x7f55c3f26e50>,
#  <__main__.ASFProject at 0x7f55c3f26eb0>,
#  <__main__.ASFProject at 0x7f55c3f26f10>,
#  <__main__.ASFProject at 0x7f55c3f26f70>,
#  <__main__.ASFProject at 0x7f55c3f26fd0>,
#  <__main__.ASFProject at 0x7f55c3f29070>,
#  <__main__.ASFProject at 0x7f55c3f290d0>,
#  <__main__.ASFProject at 0x7f55c3f29130>,
#  <__main__.ASFProject at 0x7f55c3f29190>,
#  <__main__.ASFProject at 0x7f55c3f291f0>,
#  <__main__.ASFProject at 0x7f55c3f29250>,
#  <__main__.ASFProject at 0x7f55c3f292b0>,
#  <__main__.ASFProject at 0x7f55c3f29310>,
#  <__main__.ASFProject at 0x7f55c3f29370>,
#  <__main__.ASFProject at 0x7f55c3f293d0>,
#  <__main__.ASFProject at 0x7f55c3f29430>,
#  <__main__.ASFProject at 0x7f55c3f29490>,
#  <__main__.ASFProject at 0x7f55c3f294f0>,
#  <__main__.ASFProject at 0x7f55c3f29550>,
#  <__main__.ASFProject at 0x7f55c3f295b0>,
#  <__main__.ASFProject at 0x7f55c3f29610>,
#  <__main__.ASFProject at 0x7f55c3f29670>,
#  <__main__.ASFProject at 0x7f55c3f296d0>,
#  <__main__.ASFProject at 0x7f55c3f29730>,
#  <__main__.ASFProject at 0x7f55c3f29790>,
#  <__main__.ASFProject at 0x7f55c3f297f0>,
#  <__main__.ASFProject at 0x7f55c3f29850>,
#  <__main__.ASFProject at 0x7f55c3f298b0>,
#  <__main__.ASFProject at 0x7f55c3f29910>,
#  <__main__.ASFProject at 0x7f55c3f29970>,
#  <__main__.ASFProject at 0x7f55c3f299d0>,
#  <__main__.ASFProject at 0x7f55c3f29a30>,
#  <__main__.ASFProject at 0x7f55c3f29a90>,
#  <__main__.ASFProject at 0x7f55c3f29af0>,
#  <__main__.ASFProject at 0x7f55c3f29b50>,
#  <__main__.ASFProject at 0x7f55c3f29bb0>,
#  <__main__.ASFProject at 0x7f55c3f29c10>,
#  <__main__.ASFProject at 0x7f55c3f29c70>]

# %%
len(result)
# Out:
# 265

# %%
result
# Out:
# [{'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []},
#  {'lifecycle': 0,
#   't_dev_nodes': [],
#   't_file_nodes': [],
#   't_edges': [],
#   's_nodes': [],
#   's_edges': [],
#   't_num_dev_per_file': [],
#   't_num_file_per_dev': []}]
