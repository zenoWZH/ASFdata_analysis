# %%
import modin.pandas as mipd
import os
import time
import pandas as pd
from tqdm import tqdm
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
time_resolution = 14
time_window = 5
lk_path = '/mnt/data0/lkyin/'
c_path = './data_smoothed'+str(time_resolution+time_window)+'/commits/'
e_path = './data_smoothed'+str(time_resolution+time_window)+'/emails/'
mix_path = './data_smoothed'+str(time_resolution+time_window)+'/mix/'

# %% [markdown]
# ## Technique Network
#
# + View the Dataset here, read from the saved csv
# ++ Route('/mnt/data0/lkyin/network_data/emails/')

# %% [markdown]
# ## ASF Techinical Network Construction from Likang
# + Using NetworkX for analysis
#     + https://www.osgeo.cn/networkx/tutorial.html#attributes
#
#     + Use Pandas with NetworkX https://www.jianshu.com/p/11456474d8a5
#
# + How this network is constructed (Data already saved as commits for each project each month):
#     + Tow features: "is_bot" as False and "is_coding" as True
#     + Author is not null (SVN has 'noauthor')
#     + For each row:
#         + Check if file name exist as node
#         + Add file as Node
#         + Edges saved in technical_net as a set
#         + for each commit on each file, weight +1
#     + Use technical_net to construct graph
#         + Network attributes from the dictionary: https://www.osgeo.cn/networkx/tutorial.html#attributes

# %%
projects = os.listdir(c_path)
projects.sort(key= lambda x:int(x.split('__')[1].split('.')[0]))
to_path = './network_data_smoothed'+str(time_resolution+time_window)+'/commits/'
if not os.path.exists(to_path):
    os.makedirs(to_path)
gx_technets = []
for project in tqdm(projects):
    technical_net = {}
    project_name, period = project.replace('.csv', '').split('__')
    fname = project
    if not os.path.exists(c_path+fname):
        continue
    df = pd.read_csv(c_path+fname)
    df.query('is_bot == False and is_coding == True', inplace=True)
    df = df[df['dealised_author_full_name'].notna()]
    for index, row in df.iterrows():
        file_path = row['file_name']
        # file extension = '.' + file_path.split('/')[-1].split('.')[-1].split(' ')[0]
        file_name = file_path.split('/')[-1]
        author_name = row['dealised_author_full_name']
        if file_name not in technical_net:
            technical_net[file_name] = {}
        if author_name not in technical_net[file_name]:
            technical_net[file_name][author_name] = {}
            technical_net[file_name][author_name]['weight'] = 0
        technical_net[file_name][author_name]['weight'] += 1

    #save as directed graph
    g = nx.DiGraph(technical_net)
    # add disconnected nodes
    g.add_nodes_from(technical_net.keys())
    nx.write_edgelist(g, to_path + '{}__{}.edgelist'.format(project_name, str(period)), delimiter='##', data=["weight"])
    gx_technets.append(g)
# Out:
#   7%|▋         | 532/8094 [00:26<05:43, 22.00it/s]

# %%
technical_net
# Out:
# {'Release.java': {'Glen Mazza': {'weight': 7}},
#  'SisterSites.jsp': {'Glen Mazza': {'weight': 1}},
#  'rss.jsp': {'Glen Mazza': {'weight': 1}},
#  'release.mdtext': {'Glen Mazza': {'weight': 4}},
#  'Captcha.jsp': {'Glen Mazza': {'weight': 1}},
#  'Comment.jsp': {'Glen Mazza': {'weight': 1}},
#  'CookieError.jsp': {'Glen Mazza': {'weight': 1}},
#  'Delete.jsp': {'Glen Mazza': {'weight': 1}},
#  'DeleteGroup.jsp': {'Glen Mazza': {'weight': 1}},
#  'Diff.jsp': {'Glen Mazza': {'weight': 1}},
#  'Edit.jsp': {'Glen Mazza': {'weight': 1}},
#  'EditGroup.jsp': {'Glen Mazza': {'weight': 1}},
#  'Error.jsp': {'Glen Mazza': {'weight': 1}},
#  'Group.jsp': {'Glen Mazza': {'weight': 1}},
#  'Install.jsp': {'Glen Mazza': {'weight': 1}},
#  'Login.jsp': {'Glen Mazza': {'weight': 1}},
#  'LoginForm.jsp': {'Glen Mazza': {'weight': 1}},
#  'LostPassword.jsp': {'Glen Mazza': {'weight': 1}},
#  'Message.jsp': {'Glen Mazza': {'weight': 1}},
#  'NewBlogEntry.jsp': {'Glen Mazza': {'weight': 1}},
#  'NewGroup.jsp': {'Glen Mazza': {'weight': 1}},
#  'PageInfo.jsp': {'Glen Mazza': {'weight': 1}},
#  'PageModified.jsp': {'Glen Mazza': {'weight': 1}},
#  'Preview.jsp': {'Glen Mazza': {'weight': 1}},
#  'Rename.jsp': {'Glen Mazza': {'weight': 1}},
#  'Search.jsp': {'Glen Mazza': {'weight': 1}},
#  'Upload.jsp': {'Glen Mazza': {'weight': 1}},
#  'UserPreferences.jsp': {'Glen Mazza': {'weight': 1}},
#  'Wiki.jsp': {'Glen Mazza': {'weight': 1}},
#  'Workflow.jsp': {'Glen Mazza': {'weight': 1}},
#  'Admin.jsp': {'Glen Mazza': {'weight': 1}},
#  'SecurityConfig.jsp': {'Glen Mazza': {'weight': 1}},
#  'AJAXCategories.jsp': {'Glen Mazza': {'weight': 1}},
#  'AJAXPreview.jsp': {'Glen Mazza': {'weight': 1}},
#  'AJAXSearch.jsp': {'Glen Mazza': {'weight': 1}},
#  'AttachmentTab.jsp': {'Glen Mazza': {'weight': 1}},
#  'CommentContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'ConflictContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'DiffContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'DiffTab.jsp': {'Glen Mazza': {'weight': 1}},
#  'DisplayMessage.jsp': {'Glen Mazza': {'weight': 1}},
#  'EditContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'EditGroupContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'EditTemplate.jsp': {'Glen Mazza': {'weight': 1}},
#  'Favorites.jsp': {'Glen Mazza': {'weight': 1}},
#  'FindContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'Footer.jsp': {'Glen Mazza': {'weight': 1}},
#  'GroupContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'GroupTab.jsp': {'Glen Mazza': {'weight': 1}},
#  'Header.jsp': {'Glen Mazza': {'weight': 1}},
#  'InfoContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'LoginContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'NewGroupContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'PageActionsBottom.jsp': {'Glen Mazza': {'weight': 1}},
#  'PageActionsTop.jsp': {'Glen Mazza': {'weight': 1}},
#  'PageContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'PageTab.jsp': {'Glen Mazza': {'weight': 1}},
#  'PreferencesContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'PreferencesTab.jsp': {'Glen Mazza': {'weight': 1}},
#  'PreviewContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'ProfileTab.jsp': {'Glen Mazza': {'weight': 1}},
#  'SearchBox.jsp': {'Glen Mazza': {'weight': 1}},
#  'UploadTemplate.jsp': {'Glen Mazza': {'weight': 1}},
#  'UserBox.jsp': {'Glen Mazza': {'weight': 1}},
#  'ViewTemplate.jsp': {'Glen Mazza': {'weight': 1}},
#  'WorkflowContent.jsp': {'Glen Mazza': {'weight': 1}},
#  'AdminTemplate.jsp': {'Glen Mazza': {'weight': 1}},
#  'UserManagement.jsp': {'Glen Mazza': {'weight': 1}},
#  'commonheader.jsp': {'Glen Mazza': {'weight': 1}},
#  'index.mdtext': {'Glen Mazza': {'weight': 3}},
#  'changelog.mdtext': {'Glen Mazza': {'weight': 4}},
#  'SearchResult.java': {'Glen Mazza': {'weight': 1}},
#  'StringTransmutator.java': {'Glen Mazza': {'weight': 1}},
#  'WikiContext.java': {'Glen Mazza': {'weight': 1}},
#  'WikiProvider.java': {'Glen Mazza': {'weight': 1}},
#  'FilterManager.java': {'Glen Mazza': {'weight': 1}},
#  'PluginManager.java': {'Glen Mazza': {'weight': 1}},
#  'PageFilter.java': {'Glen Mazza': {'weight': 2}},
#  'WikiPlugin.java': {'Glen Mazza': {'weight': 2}},
#  'DynamicAttachmentProvider.java': {'Glen Mazza': {'weight': 1}},
#  'Authorizer.java': {'Glen Mazza': {'weight': 1}},
#  'AclEntry.java': {'Glen Mazza': {'weight': 1}},
#  'AclManager.java': {'Glen Mazza': {'weight': 1}},
#  'GroupDatabase.java': {'Glen Mazza': {'weight': 1}},
#  'WebAuthorizer.java': {'Glen Mazza': {'weight': 1}},
#  'WikiCallbackHandler.java': {'Glen Mazza': {'weight': 1}},
#  'UserDatabase.java': {'Glen Mazza': {'weight': 1}},
#  'UserProfile.java': {'Glen Mazza': {'weight': 1}},
#  'DiffProvider.java': {'Glen Mazza': {'weight': 1}},
#  'WikiEventListener.java': {'Glen Mazza': {'weight': 1}},
#  'HeadingListener.java': {'Glen Mazza': {'weight': 1}},
#  'ParserStagePlugin.java': {'Glen Mazza': {'weight': 1}},
#  'VersioningProvider.java': {'Glen Mazza': {'weight': 1}},
#  'WikiAttachmentProvider.java': {'Glen Mazza': {'weight': 1}},
#  'WikiPageProvider.java': {'Glen Mazza': {'weight': 1}},
#  'SearchManager.java': {'Glen Mazza': {'weight': 1}},
#  'SearchProvider.java': {'Glen Mazza': {'weight': 1}},
#  'ParamHandler.java': {'Glen Mazza': {'weight': 1}},
#  'TranslateTag.java': {'Glen Mazza': {'weight': 1}},
#  'Command.java': {'Glen Mazza': {'weight': 1}},
#  'CommandResolver.java': {'Glen Mazza': {'weight': 2}},
#  'GenericHTTPHandler.java': {'Glen Mazza': {'weight': 1}},
#  'WikiServletFilter.java': {'Glen Mazza': {'weight': 1}},
#  'AdminBean.java': {'Glen Mazza': {'weight': 1}},
#  'URLConstructor.java': {'Glen Mazza': {'weight': 1}},
#  'Watchable.java': {'Glen Mazza': {'weight': 1}},
#  'Step.java': {'Glen Mazza': {'weight': 1}},
#  'WikiRPCHandler.java': {'Glen Mazza': {'weight': 1}},
#  'WikiSession.java': {'Glen Mazza': {'weight': 1}},
#  'AuthenticationManager.java': {'Glen Mazza': {'weight': 1}},
#  'AuthorizationManager.java': {'Glen Mazza': {'weight': 2}},
#  'SecurityVerifier.java': {'Glen Mazza': {'weight': 2}},
#  'UserManager.java': {'Glen Mazza': {'weight': 2}},
#  'GroupManager.java': {'Glen Mazza': {'weight': 1}},
#  'Role.java': {'Glen Mazza': {'weight': 1}},
#  'AllPermission.java': {'Glen Mazza': {'weight': 1}},
#  'GroupPermission.java': {'Glen Mazza': {'weight': 1}},
#  'PagePermission.java': {'Glen Mazza': {'weight': 1}},
#  'WikiPermission.java': {'Glen Mazza': {'weight': 1}},
#  'PropertyReader.java': {'Glen Mazza': {'weight': 1}},
#  'GroupPrincipal.java': {'Glen Mazza': {'weight': 1}},
#  'WikiPrincipal.java': {'Glen Mazza': {'weight': 1}},
#  'UnresolvedPrincipal.java': {'Glen Mazza': {'weight': 1}},
#  'AbstractLoginModule.java': {'Glen Mazza': {'weight': 1}},
#  'PrincipalWrapper.java': {'Glen Mazza': {'weight': 1}},
#  'WebContainerCallbackHandler.java': {'Glen Mazza': {'weight': 1}},
#  'PermissionFactory.java': {'Glen Mazza': {'weight': 1}},
#  'WikiEventManager.java': {'Glen Mazza': {'weight': 1}},
#  'WikiSecurityEvent.java': {'Glen Mazza': {'weight': 1}},
#  'WorkflowEvent.java': {'Glen Mazza': {'weight': 1}},
#  'JSPWikiMarkupParser.java': {'Glen Mazza': {'weight': 2}},
#  'Image.java': {'Glen Mazza': {'weight': 1}},
#  'CachingAttachmentProvider.java': {'Glen Mazza': {'weight': 1}},
#  'CachingProvider.java': {'Glen Mazza': {'weight': 1}},
#  'AtomFeed.java': {'Glen Mazza': {'weight': 1}},
#  'GroupCommand.java': {'Glen Mazza': {'weight': 1}},
#  'InputValidator.java': {'Glen Mazza': {'weight': 1}},
#  'PageCommand.java': {'Glen Mazza': {'weight': 2}},
#  'RedirectCommand.java': {'Glen Mazza': {'weight': 1}},
#  'TemplateManager.java': {'Glen Mazza': {'weight': 1}},
#  'WikiCommand.java': {'Glen Mazza': {'weight': 1}},
#  'DefaultURLConstructor.java': {'Glen Mazza': {'weight': 2}},
#  'TextUtil.java': {'Glen Mazza': {'weight': 1}},
#  'SimpleNotification.java': {'Glen Mazza': {'weight': 1}},
#  'news.mdtext': {'Glen Mazza': {'weight': 1}},
#  'WikiEventUtils.java': {'Glen Mazza': {'weight': 1}},
#  'LinkParser.java': {'Glen Mazza': {'weight': 1}},
#  'SearchManagerTest.java': {'Glen Mazza': {'weight': 1}},
#  'AttachmentServlet.java': {'Glen Mazza': {'weight': 1}},
#  'JDBCGroupDatabase.java': {'Glen Mazza': {'weight': 1}},
#  'XMLGroupDatabase.java': {'Glen Mazza': {'weight': 1}},
#  'JDBCUserDatabase.java': {'Glen Mazza': {'weight': 1}},
#  'DefaultFilterManager.java': {'Glen Mazza': {'weight': 1}},
#  'FormClose.java': {'Glen Mazza': {'weight': 1}},
#  'RSSThread.java': {'Glen Mazza': {'weight': 1}},
#  'ParamTag.java': {'Glen Mazza': {'weight': 1}},
#  'HttpUtil.java': {'Glen Mazza': {'weight': 1}},
#  'HumanComparator.java': {'Glen Mazza': {'weight': 1}}}

# %%
#nx.draw(g, with_labels=True, font_weight='bold')
nx.draw(g,
    with_labels=True,
    #pos = nx.sprint_layout(g),
    #node_color=color_list,
    edge_color='k',
    node_size=100,
    node_shape='o',
    linewidths=2,
    width=1.0,
    alpha=0.55,
    style='solid',
    font_size=9,
    font_color='k'
)

# %% [markdown]
# ## ASF Social Networks Construction From Likang
#
# + How this network is constructed (Data already saved as commits for each project each month):
#     + Tow features: "is_bot" as False and "is_coding" as True
#     + Author is not null
#     + For each email:
#         + Check if this email have previous references, if not, quit and go next
#         + Add previous authors as Nodes
#         + Edges saved in social_net as a node
#         + for each email sent to previous edges on each file, mutually (sender to previous & previous to sender) weight +1

# %%
to_path = './network_data_smoothed'+str(time_resolution+time_window)+'/emails/'
if not os.path.exists(to_path):
    os.makedirs(to_path)

projects = os.listdir(e_path)
projects.sort(key= lambda x:int(x.split('__')[1].split('.')[0]))
gx_socialnets = []
for project in tqdm(projects):

    social_net = {}
    emailID_to_author = {}
    project_name, period = project.replace('.csv', '').split('__')
    fname = project
    if not os.path.exists(e_path+fname):
        continue
    df = pd.read_csv(e_path+fname)
    df.query('is_bot == False', inplace=True)
    df = df[df['dealised_author_full_name'].notna()]
    
    for index, row in df.iterrows():
        message_id = row['message_id'].strip()
        # print(row['dealised_author_full_name'])
        sender_name = row['dealised_author_full_name']
        emailID_to_author[message_id] = sender_name

    # raise KeyError
    for index, row in df.iterrows():
        message_id = row['message_id']
        references = row['references']
        sender_name = row['dealised_author_full_name']

        # ignores if this email does not to previous emails
        if pd.isna(references) or references == 'None':
            continue

        references = [r.strip() for r in references.replace('\n', ' ').replace('\t', ' ').split(' ') if r.strip()]

        # deal with the issue that a line breaker exists in message_id:
        # e.g., <4\n829AB62.6000302@apache.org>
        new_refs = set()
        for i in range(len(references)-1):
            if '<' in references[i] and '>' not in references[i] and '<' not in references[i+1] and '>' in references[i+1]:
                new_refs.add(references[i] + references[i+1])
        for r in references:
            if '<' in r and '>' in r:
                new_refs.add(r)

        references = new_refs
        for reference_id in references:
            if reference_id not in emailID_to_author:
                continue
            prev_author = emailID_to_author[reference_id]
            # if it's the same person, continue
            if prev_author == sender_name:
                continue
            if sender_name not in social_net:
                social_net[sender_name] = {}
            if prev_author not in social_net:
                social_net[prev_author] = {}

            # if node B replies node A, it means B sends signal to A
            if prev_author not in social_net[sender_name]:
                social_net[sender_name][prev_author] = {}
                social_net[sender_name][prev_author]['weight'] = 0
            social_net[sender_name][prev_author]['weight'] += 1

            # if node B replies node A, it means A also sent signal to B
            if sender_name not in social_net[prev_author]:
                social_net[prev_author][sender_name] = {}
                social_net[prev_author][sender_name]['weight'] = 0
            social_net[prev_author][sender_name]['weight'] += 1

    #save as directed graph
    g = nx.DiGraph(social_net)
    # add disconnected nodes
    g.add_nodes_from(social_net.keys())
    nx.write_edgelist(g, to_path + '{}__{}.edgelist'.format(project_name, str(period)), delimiter='##', data=["weight"])
    gx_socialnets.append(g)
# Out:
# 100%|██████████| 11196/11196 [03:18<00:00, 56.28it/s]

# %%
projects.sort(key= lambda x:int(x.split('__')[1].split('.')[0]))
projects
# Out:
# ['atlas__001.csv',
#  'kafka__001.csv',
#  'jackrabbit__001.csv',
#  'juneau__001.csv',
#  's2graph__001.csv',
#  'sentry__001.csv',
#  'libcloud__001.csv',
#  'druid__001.csv',
#  'provisionr__001.csv',
#  'shardingsphere__001.csv',
#  'flex__001.csv',
#  'felix__001.csv',
#  'flume__001.csv',
#  'click__001.csv',
#  'lenya__001.csv',
#  'knox__001.csv',
#  'cotton__001.csv',
#  'olio__001.csv',
#  'spark__001.csv',
#  'hise__001.csv',
#  'ofbiz__001.csv',
#  'datafu__001.csv',
#  'ode__001.csv',
#  'subversion__001.csv',
#  'oodt__001.csv',
#  'pulsar__001.csv',
#  'openmeetings__001.csv',
#  'falcon__001.csv',
#  'tashi__001.csv',
#  'lens__001.csv',
#  'helix__001.csv',
#  'cassandra__001.csv',
#  'etch__001.csv',
#  'shiro__001.csv',
#  'storm__001.csv',
#  'oozie__001.csv',
#  'ranger__001.csv',
#  'depot__001.csv',
#  'johnzon__001.csv',
#  'jclouds__001.csv',
#  'dolphinscheduler__001.csv',
#  'streams__001.csv',
#  'tika__001.csv',
#  'superset__001.csv',
#  'empire__001.csv',
#  'daffodil__001.csv',
#  'vxquery__001.csv',
#  'concerted__001.csv',
#  'stdcxx__001.csv',
#  'buildr__001.csv',
#  'zeta__001.csv',
#  'mynewt__001.csv',
#  'openwebbeans__001.csv',
#  'kudu__001.csv',
#  'isis__001.csv',
#  'zipkin__001.csv',
#  'rocketmq__001.csv',
#  'singa__001.csv',
#  'devicemap__001.csv',
#  'jdo__001.csv',
#  'corinthia__001.csv',
#  'kato__001.csv',
#  'bookkeeper__001.csv',
#  'metamodel__001.csv',
#  'pirk__001.csv',
#  'shindig__001.csv',
#  'nutch__001.csv',
#  'datasketches__001.csv',
#  'clerezza__001.csv',
#  'deltaspike__001.csv',
#  'pig__001.csv',
#  'ivy__001.csv',
#  'myriad__001.csv',
#  'tamaya__001.csv',
#  'onami__001.csv',
#  'sirona__001.csv',
#  'myfaces__001.csv',
#  'lucy__001.csv',
#  'ripple__001.csv',
#  'spamassassin__001.csv',
#  'kitty__001.csv',
#  'chemistry__001.csv',
#  'nmaven__001.csv',
#  'hudi__001.csv',
#  'systemml__001.csv',
#  'vcl__001.csv',
#  'flink__001.csv',
#  'adffaces__001.csv',
#  'imperius__001.csv',
#  'echarts__001.csv',
#  'cordova__001.csv',
#  'mnemonic__001.csv',
#  'photark__001.csv',
#  'tinkerpop__001.csv',
#  'hcatalog__001.csv',
#  'mrql__001.csv',
#  'iota__001.csv',
#  'horn__001.csv',
#  'allura__001.csv',
#  's4__001.csv',
#  'tephra__001.csv',
#  'geronimo__001.csv',
#  'xmlbeans__001.csv',
#  'socialsite__001.csv',
#  'ant__001.csv',
#  'ambari__001.csv',
#  'muse__001.csv',
#  'wookie__001.csv',
#  'curator__001.csv',
#  'juddi__001.csv',
#  'openoffice__001.csv',
#  'madlib__001.csv',
#  'stanbol__001.csv',
#  'slider__001.csv',
#  'tuscany__001.csv',
#  'airavata__001.csv',
#  'mrunit__001.csv',
#  'cxf__001.csv',
#  'gearpump__001.csv',
#  'thrift__001.csv',
#  'avalon__001.csv',
#  'samza__001.csv',
#  'pivot__001.csv',
#  'weex__001.csv',
#  'phoenix__001.csv',
#  'pubscribe__001.csv',
#  'servicecomb__001.csv',
#  'odf__001.csv',
#  'predictionio__001.csv',
#  'bloodhound__001.csv',
#  'trafficcontrol__001.csv',
#  'beam__001.csv',
#  'iceberg__001.csv',
#  'guacamole__001.csv',
#  'tapestry__001.csv',
#  'openaz__001.csv',
#  'triplesoup__001.csv',
#  'pdfbox__001.csv',
#  'derby__001.csv',
#  'rcf__001.csv',
#  'kabuki__001.csv',
#  'sanselan__001.csv',
#  'carbondata__001.csv',
#  'joshua__001.csv',
#  'metron__001.csv',
#  'plc4x__001.csv',
#  'ibatis__001.csv',
#  'deltacloud__001.csv',
#  'bigtop__001.csv',
#  'opennlp__001.csv',
#  'sqoop__001.csv',
#  'openjpa__001.csv',
#  'htrace__001.csv',
#  'roller__001.csv',
#  'awf__001.csv',
#  'amaterasu__001.csv',
#  'any23__001.csv',
#  'tvm__001.csv',
#  'xap__001.csv',
#  'sling__001.csv',
#  'iotdb__001.csv',
#  'hawq__001.csv',
#  'jena__001.csv',
#  'olingo__001.csv',
#  'ftpserver__001.csv',
#  'harmony__001.csv',
#  'cmda__001.csv',
#  'struts__001.csv',
#  'directory__001.csv',
#  'stonehenge__001.csv',
#  'ace__001.csv',
#  'eagle__001.csv',
#  'couchdb__001.csv',
#  'gora__001.csv',
#  'apisix__001.csv',
#  'ariatosca__001.csv',
#  'uima__001.csv',
#  'marmotta__001.csv',
#  'stratos__001.csv',
#  'ctakes__001.csv',
#  'whirr__001.csv',
#  'blur__001.csv',
#  'netbeans__001.csv',
#  'hama__001.csv',
#  'crunch__001.csv',
#  'omid__001.csv',
#  'droids__001.csv',
#  'commons__001.csv',
#  'tez__001.csv',
#  'zeppelin__001.csv',
#  'accumulo__001.csv',
#  'alois__001.csv',
#  'abdera__001.csv',
#  'calcite__001.csv',
#  'climate__001.csv',
#  'drill__001.csv',
#  'directmemory__001.csv',
#  'twill__001.csv',
#  'openwhisk__001.csv',
#  'samoa__001.csv',
#  'cloudstack__001.csv',
#  'warble__001.csv',
#  'celix__001.csv',
#  'sis__001.csv',
#  'freemarker__001.csv',
#  'edgent__001.csv',
#  'ratis__001.csv',
#  'skywalking__001.csv',
#  'gossip__001.csv',
#  'jspwiki__001.csv',
#  'griffin__001.csv',
#  'rave__001.csv',
#  'airflow__001.csv',
#  'tajo__001.csv',
#  'giraph__001.csv',
#  'apex__001.csv',
#  'ignite__001.csv',
#  'asterixdb__001.csv',
#  'chukwa__001.csv',
#  'parquet__001.csv',
#  'wicket__001.csv',
#  'aurora__001.csv',
#  'unomi__001.csv',
#  'syncope__001.csv',
#  'mesos__001.csv',
#  'trafficserver__001.csv',
#  'commonsrdf__001.csv',
#  'mod_ftp__001.csv',
#  'geode__001.csv',
#  'fineract__001.csv',
#  'juice__001.csv',
#  'gobblin__001.csv',
#  'taverna__001.csv',
#  'oltu__001.csv',
#  'groovy__001.csv',
#  'agila__001.csv',
#  'river__001.csv',
#  'usergrid__001.csv',
#  'quickstep__001.csv',
#  'brooklyn__001.csv',
#  'servicemix__001.csv',
#  'lokahi__001.csv',
#  'activemq__001.csv',
#  'bluesky__001.csv',
#  'trafodion__001.csv',
#  'esme__001.csv',
#  'lucenenet__001.csv',
#  'impala__001.csv',
#  'fluo__001.csv',
#  'wave__001.csv',
#  'batchee__001.csv',
#  'aries__001.csv',
#  'manifoldcf__001.csv',
#  'solr__001.csv',
#  'qpid__001.csv',
#  'yoko__001.csv',
#  'beehive__001.csv',
#  'pinot__001.csv',
#  'kalumet__001.csv',
#  'dubbo__001.csv',
#  'nuvem__001.csv',
#  'reef__001.csv',
#  'hdt__001.csv',
#  'kylin__001.csv',
#  'rya__001.csv',
#  'graffito__001.csv',
#  'cayenne__001.csv',
#  'npanday__001.csv',
#  'nifi__001.csv',
#  'wink__001.csv',
#  'heraldry__001.csv',
#  'synapse__001.csv',
#  'bval__001.csv',
#  'airavata__002.csv',
#  'sentry__002.csv',
#  'twill__002.csv',
#  'tapestry__002.csv',
#  'celix__002.csv',
#  'ambari__002.csv',
#  'datafu__002.csv',
#  'cmda__002.csv',
#  'photark__002.csv',
#  'airflow__002.csv',
#  'jclouds__002.csv',
#  'shindig__002.csv',
#  'rocketmq__002.csv',
#  'curator__002.csv',
#  'whirr__002.csv',
#  'amaterasu__002.csv',
#  'ofbiz__002.csv',
#  'hudi__002.csv',
#  'mrql__002.csv',
#  'juice__002.csv',
#  'agila__002.csv',
#  'tika__002.csv',
#  'juneau__002.csv',
#  'tinkerpop__002.csv',
#  'directmemory__002.csv',
#  'falcon__002.csv',
#  'wink__002.csv',
#  'wicket__002.csv',
#  'openaz__002.csv',
#  'oozie__002.csv',
#  'chemistry__002.csv',
#  'gossip__002.csv',
#  'syncope__002.csv',
#  'iota__002.csv',
#  'tashi__002.csv',
#  'openwebbeans__002.csv',
#  'xmlbeans__002.csv',
#  'lucy__002.csv',
#  'tuscany__002.csv',
#  'kylin__002.csv',
#  'xap__002.csv',
#  'ivy__002.csv',
#  'usergrid__002.csv',
#  'eagle__002.csv',
#  'river__002.csv',
#  'oltu__002.csv',
#  'climate__002.csv',
#  'flink__002.csv',
#  'knox__002.csv',
#  'mynewt__002.csv',
#  'gobblin__002.csv',
#  'spark__002.csv',
#  'libcloud__002.csv',
#  'kitty__002.csv',
#  'apex__002.csv',
#  'trafficcontrol__002.csv',
#  'chukwa__002.csv',
#  'awf__002.csv',
#  'mod_ftp__002.csv',
#  'fineract__002.csv',
#  'joshua__002.csv',
#  'datasketches__002.csv',
#  'any23__002.csv',
#  'oodt__002.csv',
#  'stratos__002.csv',
#  'shardingsphere__002.csv',
#  'vxquery__002.csv',
#  'nmaven__002.csv',
#  'droids__002.csv',
#  'giraph__002.csv',
#  'flume__002.csv',
#  'stanbol__002.csv',
#  'opennlp__002.csv',
#  'warble__002.csv',
#  'asterixdb__002.csv',
#  'plc4x__002.csv',
#  'gearpump__002.csv',
#  'ratis__002.csv',
#  'muse__002.csv',
#  'thrift__002.csv',
#  'bookkeeper__002.csv',
#  'johnzon__002.csv',
#  'lenya__002.csv',
#  'cordova__002.csv',
#  'iceberg__002.csv',
#  'harmony__002.csv',
#  'hdt__002.csv',
#  'geronimo__002.csv',
#  'kalumet__002.csv',
#  'storm__002.csv',
#  'synapse__002.csv',
#  'graffito__002.csv',
#  'sirona__002.csv',
#  'corinthia__002.csv',
#  'calcite__002.csv',
#  'gora__002.csv',
#  'felix__002.csv',
#  'kafka__002.csv',
#  'trafodion__002.csv',
#  'kabuki__002.csv',
#  'etch__002.csv',
#  'directory__002.csv',
#  'solr__002.csv',
#  'openmeetings__002.csv',
#  'cxf__002.csv',
#  'marmotta__002.csv',
#  'griffin__002.csv',
#  's4__002.csv',
#  'madlib__002.csv',
#  'mrunit__002.csv',
#  'netbeans__002.csv',
#  'crunch__002.csv',
#  'rave__002.csv',
#  'superset__002.csv',
#  'heraldry__002.csv',
#  'singa__002.csv',
#  'jackrabbit__002.csv',
#  'dolphinscheduler__002.csv',
#  'jena__002.csv',
#  'dubbo__002.csv',
#  'deltacloud__002.csv',
#  'echarts__002.csv',
#  'ace__002.csv',
#  'metron__002.csv',
#  'esme__002.csv',
#  'manifoldcf__002.csv',
#  'ariatosca__002.csv',
#  'spamassassin__002.csv',
#  'subversion__002.csv',
#  'hama__002.csv',
#  'deltaspike__002.csv',
#  'freemarker__002.csv',
#  'openwhisk__002.csv',
#  'alois__002.csv',
#  'stonehenge__002.csv',
#  'imperius__002.csv',
#  'taverna__002.csv',
#  'zeta__002.csv',
#  'edgent__002.csv',
#  'phoenix__002.csv',
#  'guacamole__002.csv',
#  'systemml__002.csv',
#  'tez__002.csv',
#  'weex__002.csv',
#  'commons__002.csv',
#  'provisionr__002.csv',
#  'vcl__002.csv',
#  'htrace__002.csv',
#  'tephra__002.csv',
#  'fluo__002.csv',
#  'openjpa__002.csv',
#  'ripple__002.csv',
#  'wookie__002.csv',
#  'stdcxx__002.csv',
#  'depot__002.csv',
#  'reef__002.csv',
#  'omid__002.csv',
#  'atlas__002.csv',
#  'beam__002.csv',
#  'nifi__002.csv',
#  'rya__002.csv',
#  's2graph__002.csv',
#  'abdera__002.csv',
#  'lokahi__002.csv',
#  'quickstep__002.csv',
#  'ode__002.csv',
#  'servicecomb__002.csv',
#  'mnemonic__002.csv',
#  'uima__002.csv',
#  'allura__002.csv',
#  'carbondata__002.csv',
#  'slider__002.csv',
#  'apisix__002.csv',
#  'servicemix__002.csv',
#  'wave__002.csv',
#  'trafficserver__002.csv',
#  'qpid__002.csv',
#  'tvm__002.csv',
#  'cassandra__002.csv',
#  'sis__002.csv',
#  'rcf__002.csv',
#  'sqoop__002.csv',
#  'druid__002.csv',
#  'adffaces__002.csv',
#  'socialsite__002.csv',
#  'jdo__002.csv',
#  'lens__002.csv',
#  'ftpserver__002.csv',
#  'skywalking__002.csv',
#  'helix__002.csv',
#  'bval__002.csv',
#  'lucenenet__002.csv',
#  'olingo__002.csv',
#  'ranger__002.csv',
#  'hawq__002.csv',
#  'buildr__002.csv',
#  'onami__002.csv',
#  'pivot__002.csv',
#  'sling__002.csv',
#  'impala__002.csv',
#  'concerted__002.csv',
#  'horn__002.csv',
#  'pdfbox__002.csv',
#  'npanday__002.csv',
#  'struts__002.csv',
#  'pinot__002.csv',
#  'devicemap__002.csv',
#  'beehive__002.csv',
#  'blur__002.csv',
#  'jspwiki__002.csv',
#  'ignite__002.csv',
#  'tamaya__002.csv',
#  'pig__002.csv',
#  'unomi__002.csv',
#  'aurora__002.csv',
#  'ctakes__002.csv',
#  'shiro__002.csv',
#  'samza__002.csv',
#  'streams__002.csv',
#  'flex__002.csv',
#  'couchdb__002.csv',
#  'kato__002.csv',
#  'derby__002.csv',
#  'cloudstack__002.csv',
#  'bloodhound__002.csv',
#  'myfaces__002.csv',
#  'juddi__002.csv',
#  'kudu__002.csv',
#  'myriad__002.csv',
#  'triplesoup__002.csv',
#  'predictionio__002.csv',
#  'pubscribe__002.csv',
#  'roller__002.csv',
#  'clerezza__002.csv',
#  'accumulo__002.csv',
#  'zeppelin__002.csv',
#  'sanselan__002.csv',
#  'ibatis__002.csv',
#  'samoa__002.csv',
#  'pulsar__002.csv',
#  'aries__002.csv',
#  'mesos__002.csv',
#  'tajo__002.csv',
#  'nutch__002.csv',
#  'yoko__002.csv',
#  'brooklyn__002.csv',
#  'olio__002.csv',
#  'daffodil__002.csv',
#  'activemq__002.csv',
#  'drill__002.csv',
#  'geode__002.csv',
#  'ant__002.csv',
#  'isis__002.csv',
#  'bluesky__002.csv',
#  'groovy__002.csv',
#  'pirk__002.csv',
#  'batchee__002.csv',
#  'click__002.csv',
#  'zipkin__002.csv',
#  'hcatalog__002.csv',
#  'parquet__002.csv',
#  'openoffice__002.csv',
#  'odf__002.csv',
#  'bigtop__002.csv',
#  'hise__002.csv',
#  'cayenne__002.csv',
#  'nuvem__002.csv',
#  'iotdb__002.csv',
#  'cotton__002.csv',
#  'commonsrdf__002.csv',
#  'empire__002.csv',
#  'metamodel__002.csv',
#  'empire__003.csv',
#  'heraldry__003.csv',
#  'stanbol__003.csv',
#  'devicemap__003.csv',
#  'shindig__003.csv',
#  'daffodil__003.csv',
#  'cassandra__003.csv',
#  'mnemonic__003.csv',
#  'ambari__003.csv',
#  'tajo__003.csv',
#  'wink__003.csv',
#  'cotton__003.csv',
#  'juice__003.csv',
#  'harmony__003.csv',
#  'gora__003.csv',
#  'juneau__003.csv',
#  'ftpserver__003.csv',
#  'samza__003.csv',
#  'lucy__003.csv',
#  'wicket__003.csv',
#  'tika__003.csv',
#  'kitty__003.csv',
#  'nuvem__003.csv',
#  'openmeetings__003.csv',
#  'weex__003.csv',
#  'yoko__003.csv',
#  'iota__003.csv',
#  'ace__003.csv',
#  'wookie__003.csv',
#  'usergrid__003.csv',
#  'myriad__003.csv',
#  's2graph__003.csv',
#  'ode__003.csv',
#  'hudi__003.csv',
#  'reef__003.csv',
#  'pubscribe__003.csv',
#  'dolphinscheduler__003.csv',
#  'mynewt__003.csv',
#  'groovy__003.csv',
#  'storm__003.csv',
#  'jspwiki__003.csv',
#  'cloudstack__003.csv',
#  'joshua__003.csv',
#  'freemarker__003.csv',
#  'pig__003.csv',
#  'gobblin__003.csv',
#  'mesos__003.csv',
#  'curator__003.csv',
#  'gearpump__003.csv',
#  'drill__003.csv',
#  'atlas__003.csv',
#  'edgent__003.csv',
#  'mrunit__003.csv',
#  'servicecomb__003.csv',
#  'streams__003.csv',
#  'pivot__003.csv',
#  'flex__003.csv',
#  'chemistry__003.csv',
#  'depot__003.csv',
#  'openwebbeans__003.csv',
#  'pinot__003.csv',
#  'myfaces__003.csv',
#  'systemml__003.csv',
#  'esme__003.csv',
#  'quickstep__003.csv',
#  'adffaces__003.csv',
#  'ignite__003.csv',
#  'trafficserver__003.csv',
#  'ctakes__003.csv',
#  'etch__003.csv',
#  'kudu__003.csv',
#  'ariatosca__003.csv',
#  'sis__003.csv',
#  'celix__003.csv',
#  'phoenix__003.csv',
#  'predictionio__003.csv',
#  'openjpa__003.csv',
#  'ofbiz__003.csv',
#  'knox__003.csv',
#  'bigtop__003.csv',
#  'thrift__003.csv',
#  'ripple__003.csv',
#  'nmaven__003.csv',
#  'pirk__003.csv',
#  'allura__003.csv',
#  'zeppelin__003.csv',
#  'brooklyn__003.csv',
#  'horn__003.csv',
#  'flink__003.csv',
#  'corinthia__003.csv',
#  'blur__003.csv',
#  'nutch__003.csv',
#  'taverna__003.csv',
#  'hcatalog__003.csv',
#  'vcl__003.csv',
#  'xmlbeans__003.csv',
#  'giraph__003.csv',
#  'guacamole__003.csv',
#  'plc4x__003.csv',
#  'airflow__003.csv',
#  'singa__003.csv',
#  'onami__003.csv',
#  'oozie__003.csv',
#  'directory__003.csv',
#  'xap__003.csv',
#  'oodt__003.csv',
#  'isis__003.csv',
#  'shiro__003.csv',
#  'sirona__003.csv',
#  'kalumet__003.csv',
#  'bluesky__003.csv',
#  'marmotta__003.csv',
#  'manifoldcf__003.csv',
#  'shardingsphere__003.csv',
#  'cxf__003.csv',
#  'tez__003.csv',
#  'tamaya__003.csv',
#  'muse__003.csv',
#  'solr__003.csv',
#  'roller__003.csv',
#  'kato__003.csv',
#  'droids__003.csv',
#  'apisix__003.csv',
#  'ivy__003.csv',
#  'qpid__003.csv',
#  'trafficcontrol__003.csv',
#  'tashi__003.csv',
#  'metron__003.csv',
#  'abdera__003.csv',
#  'bval__003.csv',
#  'johnzon__003.csv',
#  'subversion__003.csv',
#  'zeta__003.csv',
#  'sanselan__003.csv',
#  'graffito__003.csv',
#  'iotdb__003.csv',
#  'griffin__003.csv',
#  'ibatis__003.csv',
#  'calcite__003.csv',
#  'impala__003.csv',
#  'eagle__003.csv',
#  'batchee__003.csv',
#  'kabuki__003.csv',
#  'superset__003.csv',
#  'jackrabbit__003.csv',
#  'photark__003.csv',
#  'slider__003.csv',
#  'opennlp__003.csv',
#  'tvm__003.csv',
#  'lenya__003.csv',
#  'unomi__003.csv',
#  'beehive__003.csv',
#  'warble__003.csv',
#  'kafka__003.csv',
#  'synapse__003.csv',
#  'madlib__003.csv',
#  'parquet__003.csv',
#  'rocketmq__003.csv',
#  'omid__003.csv',
#  'olio__003.csv',
#  'hama__003.csv',
#  'concerted__003.csv',
#  'dubbo__003.csv',
#  'climate__003.csv',
#  'mod_ftp__003.csv',
#  'felix__003.csv',
#  'deltacloud__003.csv',
#  'hdt__003.csv',
#  'ratis__003.csv',
#  'geode__003.csv',
#  'stdcxx__003.csv',
#  'cmda__003.csv',
#  'activemq__003.csv',
#  'amaterasu__003.csv',
#  'imperius__003.csv',
#  'directmemory__003.csv',
#  'aries__003.csv',
#  'sentry__003.csv',
#  'bloodhound__003.csv',
#  'stonehenge__003.csv',
#  'openwhisk__003.csv',
#  'kylin__003.csv',
#  'asterixdb__003.csv',
#  'tinkerpop__003.csv',
#  'zipkin__003.csv',
#  'vxquery__003.csv',
#  'lucenenet__003.csv',
#  'struts__003.csv',
#  'pulsar__003.csv',
#  'provisionr__003.csv',
#  'spamassassin__003.csv',
#  'olingo__003.csv',
#  'syncope__003.csv',
#  'mrql__003.csv',
#  'accumulo__003.csv',
#  'aurora__003.csv',
#  'wave__003.csv',
#  'river__003.csv',
#  'awf__003.csv',
#  'fluo__003.csv',
#  'oltu__003.csv',
#  'trafodion__003.csv',
#  'echarts__003.csv',
#  'ranger__003.csv',
#  'nifi__003.csv',
#  'apex__003.csv',
#  'bookkeeper__003.csv',
#  'rcf__003.csv',
#  'couchdb__003.csv',
#  'whirr__003.csv',
#  'commons__003.csv',
#  'druid__003.csv',
#  'commonsrdf__003.csv',
#  'fineract__003.csv',
#  'deltaspike__003.csv',
#  'twill__003.csv',
#  'beam__003.csv',
#  'alois__003.csv',
#  'airavata__003.csv',
#  'metamodel__003.csv',
#  'datasketches__003.csv',
#  'servicemix__003.csv',
#  'buildr__003.csv',
#  'helix__003.csv',
#  'datafu__003.csv',
#  'tephra__003.csv',
#  'hawq__003.csv',
#  'click__003.csv',
#  'socialsite__003.csv',
#  'flume__003.csv',
#  'uima__003.csv',
#  'cordova__003.csv',
#  'jena__003.csv',
#  'sqoop__003.csv',
#  'geronimo__003.csv',
#  'iceberg__003.csv',
#  'npanday__003.csv',
#  'rya__003.csv',
#  'tapestry__003.csv',
#  'carbondata__003.csv',
#  'skywalking__003.csv',
#  'jclouds__003.csv',
#  'rave__003.csv',
#  'ant__003.csv',
#  'crunch__003.csv',
#  'chukwa__003.csv',
#  'pdfbox__003.csv',
#  'lens__003.csv',
#  'odf__003.csv',
#  'openoffice__003.csv',
#  's4__003.csv',
#  'openaz__003.csv',
#  'falcon__003.csv',
#  'htrace__003.csv',
#  'hise__003.csv',
#  'tuscany__003.csv',
#  'juddi__003.csv',
#  'netbeans__003.csv',
#  'stratos__003.csv',
#  'derby__003.csv',
#  'triplesoup__003.csv',
#  'jdo__003.csv',
#  'samoa__003.csv',
#  'lokahi__003.csv',
#  'libcloud__003.csv',
#  'clerezza__003.csv',
#  'sling__003.csv',
#  'gossip__003.csv',
#  'any23__003.csv',
#  'spark__003.csv',
#  'agila__003.csv',
#  'cayenne__003.csv',
#  'olingo__004.csv',
#  'gora__004.csv',
#  'agila__004.csv',
#  'libcloud__004.csv',
#  'gearpump__004.csv',
#  'samza__004.csv',
#  'ace__004.csv',
#  'juneau__004.csv',
#  'airflow__004.csv',
#  'flex__004.csv',
#  'lens__004.csv',
#  'wink__004.csv',
#  'madlib__004.csv',
#  'atlas__004.csv',
#  'spark__004.csv',
#  'joshua__004.csv',
#  'chemistry__004.csv',
#  'curator__004.csv',
#  'griffin__004.csv',
#  'ambari__004.csv',
#  'storm__004.csv',
#  'myfaces__004.csv',
#  'jena__004.csv',
#  'rocketmq__004.csv',
#  'couchdb__004.csv',
#  'kafka__004.csv',
#  'beam__004.csv',
#  'npanday__004.csv',
#  'quickstep__004.csv',
#  'horn__004.csv',
#  'pdfbox__004.csv',
#  'imperius__004.csv',
#  'manifoldcf__004.csv',
#  'unomi__004.csv',
#  'tamaya__004.csv',
#  'dubbo__004.csv',
#  'clerezza__004.csv',
#  'whirr__004.csv',
#  'aries__004.csv',
#  'lenya__004.csv',
#  'hama__004.csv',
#  'directory__004.csv',
#  'cayenne__004.csv',
#  'rya__004.csv',
#  'pirk__004.csv',
#  'helix__004.csv',
#  'allura__004.csv',
#  'river__004.csv',
#  'iotdb__004.csv',
#  'wave__004.csv',
#  'socialsite__004.csv',
#  'mrql__004.csv',
#  'zeppelin__004.csv',
#  'lucenenet__004.csv',
#  'pubscribe__004.csv',
#  'deltaspike__004.csv',
#  'wookie__004.csv',
#  'beehive__004.csv',
#  'deltacloud__004.csv',
#  'freemarker__004.csv',
#  'mnemonic__004.csv',
#  'kylin__004.csv',
#  'stonehenge__004.csv',
#  'skywalking__004.csv',
#  'awf__004.csv',
#  'impala__004.csv',
#  'slider__004.csv',
#  'servicecomb__004.csv',
#  'amaterasu__004.csv',
#  'ofbiz__004.csv',
#  'wicket__004.csv',
#  'tashi__004.csv',
#  'metamodel__004.csv',
#  'metron__004.csv',
#  'usergrid__004.csv',
#  'concerted__004.csv',
#  'hcatalog__004.csv',
#  'datafu__004.csv',
#  'onami__004.csv',
#  'zeta__004.csv',
#  'solr__004.csv',
#  'juddi__004.csv',
#  'dolphinscheduler__004.csv',
#  'nuvem__004.csv',
#  'chukwa__004.csv',
#  'tephra__004.csv',
#  'apex__004.csv',
#  'ivy__004.csv',
#  'bloodhound__004.csv',
#  'ignite__004.csv',
#  'datasketches__004.csv',
#  'triplesoup__004.csv',
#  'asterixdb__004.csv',
#  'bval__004.csv',
#  'plc4x__004.csv',
#  'yoko__004.csv',
#  'aurora__004.csv',
#  'ode__004.csv',
#  'sentry__004.csv',
#  'eagle__004.csv',
#  'fineract__004.csv',
#  'jspwiki__004.csv',
#  'openoffice__004.csv',
#  'ripple__004.csv',
#  'edgent__004.csv',
#  'bigtop__004.csv',
#  'struts__004.csv',
#  'cordova__004.csv',
#  'tajo__004.csv',
#  'flink__004.csv',
#  'rave__004.csv',
#  'servicemix__004.csv',
#  'nmaven__004.csv',
#  'falcon__004.csv',
#  'activemq__004.csv',
#  'click__004.csv',
#  'jdo__004.csv',
#  'twill__004.csv',
#  'openwebbeans__004.csv',
#  'trafficcontrol__004.csv',
#  'openjpa__004.csv',
#  'druid__004.csv',
#  'vxquery__004.csv',
#  'vcl__004.csv',
#  's4__004.csv',
#  'ant__004.csv',
#  'carbondata__004.csv',
#  'apisix__004.csv',
#  'synapse__004.csv',
#  'superset__004.csv',
#  'lucy__004.csv',
#  'directmemory__004.csv',
#  'jackrabbit__004.csv',
#  'oozie__004.csv',
#  'syncope__004.csv',
#  'pig__004.csv',
#  'droids__004.csv',
#  'htrace__004.csv',
#  'reef__004.csv',
#  'samoa__004.csv',
#  'taverna__004.csv',
#  'felix__004.csv',
#  'gobblin__004.csv',
#  'oodt__004.csv',
#  'adffaces__004.csv',
#  'zipkin__004.csv',
#  'shardingsphere__004.csv',
#  'bookkeeper__004.csv',
#  'weex__004.csv',
#  'guacamole__004.csv',
#  'mesos__004.csv',
#  'empire__004.csv',
#  'systemml__004.csv',
#  'stratos__004.csv',
#  'trafodion__004.csv',
#  'netbeans__004.csv',
#  'shiro__004.csv',
#  'batchee__004.csv',
#  'kitty__004.csv',
#  'juice__004.csv',
#  'daffodil__004.csv',
#  'ranger__004.csv',
#  'ratis__004.csv',
#  'ftpserver__004.csv',
#  'sqoop__004.csv',
#  'sanselan__004.csv',
#  'geode__004.csv',
#  'myriad__004.csv',
#  'sling__004.csv',
#  'stdcxx__004.csv',
#  'cmda__004.csv',
#  'crunch__004.csv',
#  'nifi__004.csv',
#  'esme__004.csv',
#  'accumulo__004.csv',
#  'corinthia__004.csv',
#  'hudi__004.csv',
#  'geronimo__004.csv',
#  'abdera__004.csv',
#  'predictionio__004.csv',
#  'groovy__004.csv',
#  'muse__004.csv',
#  'kato__004.csv',
#  ...]

# %%
social_net
# Out:
# {'Tom Barber': {'David Fisher': {'weight': 2}},
#  'David Fisher': {'Tom Barber': {'weight': 2},
#   'Nick Burch': {'weight': 1},
#   'Danese Cooper': {'weight': 1},
#   'Yegor Kozlov': {'weight': 2},
#   'Svante Schubert': {'weight': 2}},
#  'Andrew Willerding': {'Svante Schubert': {'weight': 12}},
#  'Svante Schubert': {'Andrew Willerding': {'weight': 12},
#   'David Fisher': {'weight': 2},
#   'Yegor Kozlov': {'weight': 1}},
#  'Nick Burch': {'David Fisher': {'weight': 1}},
#  'Danese Cooper': {'David Fisher': {'weight': 1}},
#  'Yegor Kozlov': {'David Fisher': {'weight': 2},
#   'Svante Schubert': {'weight': 1}}}

# %%
#nx.draw(g, with_labels=True, font_weight='bold')
nx.draw(g,
    with_labels=True,
    #pos = nx.sprint_layout(g),
    #node_color=color_list,
    edge_color='k',
    node_size=100,
    node_shape='o',
    linewidths=2,
    width=1.0,
    alpha=0.55,
    style='solid',
    font_size=9,
    font_color='k'
)
